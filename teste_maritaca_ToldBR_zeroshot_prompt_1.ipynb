# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # chaves da API
# eduluz@gmail
#
# 103274251389094881747$f34de79813883385e129ca9cc225bfde235e75556bc5bdde7f5e4a56d37fc91f
#
# eduluz@ufop
#
# 114275914826369140162$10dd060637cafc0588838170be9e21259d265962d7a4d3353d85112da3d3b0c3
#
# aliced @ gmail
# 102967372526087716403$d8d4d59e5ee7cf9adee258414475cdb045ed3ded3315179fea2d13b172c4d791

# %%
import pandas as pd

# Substitua o 'caminho_do_arquivo.csv' pelo caminho real do seu arquivo CSV
arquivo_csv = '/content/drive/MyDrive/Colab Notebooks/2023/BRACIS_toxic/data/train_toldbr.csv'

# Ler o arquivo CSV
dados = pd.read_csv(arquivo_csv)

# Mostrar as primeiras linhas do DataFrame
print(dados.head())
# Out:
#                                                 text  Toxic  \
# 0  Meu nivel de amizade com isis é ela ter meu in...    1.0
# 1  rt @user @user o cara adultera dados, que fora...    1.0
# 2  @user @user @user o cara só é simplesmente o m...    1.0
# 3  eu to chorando vei vsf e eu nem staneio izone ...    1.0
# 4  tem um do jack com a msm música e agr não sei ...    0.0
#
#                                           clean_text
# 0  Meu nivel de amizade com isis é ela ter meu in...
# 1  rt @user @user o cara adultera dados, que fora...
# 2  @user @user @user o cara só é simplesmente o m...
# 3  eu to chorando vei vsf e eu nem staneio izone ...
# 4  tem um do jack com a msm música e agr não sei ...

# %%
# Selecionar colunas específicas
dados_brutos = dados.iloc[:, 0]
rotulos = dados.iloc[:, 1]
dados_preprocessados = dados.iloc[:, 2]

# Mostrar as primeiras linhas de cada coluna
print("Dados brutos:")
print(dados_brutos.head())
print("\nRótulos:")
print(rotulos.head())
print("\nDados preprocessados:")
print(dados_preprocessados.head())
# Out:
# Dados brutos:
# 0    Meu nivel de amizade com isis é ela ter meu in...
# 1    rt @user @user o cara adultera dados, que fora...
# 2    @user @user @user o cara só é simplesmente o m...
# 3    eu to chorando vei vsf e eu nem staneio izone ...
# 4    tem um do jack com a msm música e agr não sei ...
# Name: text, dtype: object
#
# Rótulos:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# Name: Toxic, dtype: float64
#
# Dados preprocessados:
# 0    Meu nivel de amizade com isis é ela ter meu in...
# 1    rt @user @user o cara adultera dados, que fora...
# 2    @user @user @user o cara só é simplesmente o m...
# 3    eu to chorando vei vsf e eu nem staneio izone ...
# 4    tem um do jack com a msm música e agr não sei ...
# Name: clean_text, dtype: object

# %% [markdown]
# Conta palavras no datasets de TESTE

# %%
import csv

def contar_palavras(arquivo_csv):
    numero_de_palavras = 0

    with open(arquivo_csv, 'r', encoding="utf-8") as arquivo:
        leitor = csv.reader(arquivo, delimiter=',')  # assumindo que a vírgula é o delimitador

        for linha in leitor:
            for campo in linha:
                numero_de_palavras += len(campo.split())

    return numero_de_palavras

arquivo_csv = '/content/drive/MyDrive/Colab Notebooks/2023/BRACIS_toxic/data/test_toldbr.csv'
total = contar_palavras(arquivo_csv)
print(f"O arquivo contém {total} palavras.")
# Out:
# O arquivo contém 134099 palavras.

# %% [markdown]
# Chama a APi do maritaca e faz a classificação

# %%
pip install maritalk
# Out:
# Requirement already satisfied: maritalk in /usr/local/lib/python3.10/dist-packages (0.0.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from maritalk) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->maritalk) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->maritalk) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->maritalk) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->maritalk) (2023.7.22)

# %%
import pandas as pd
import time
import requests

# Configuração da API
KEY = '114275914826369140162$10dd060637cafc0588838170be9e21259d265962d7a4d3353d85112da3d3b0c3'
URL = "https://chat.maritaca.ai/api/chat/inference"
HEADERS = {
    "authorization": f"Key {KEY}"
}

# Leitura do CSV
arquivo_csv = '/content/drive/MyDrive/Colab Notebooks/2023/BRACIS_toxic/data/test_toldbr.csv'
dados = pd.read_csv(arquivo_csv)
dados_preprocessados = dados['clean_text']

# Função para classificar texto
def classificar_texto(texto):
    data = {
        "messages": [
            {"role": "user", "content": "Você está realizando análise de texto. O texto a seguir foi utilizado em um contexto de uma rede social. Me diga, com sim ou não, se você considera esse texto tóxico: "},
            {"role": "user", "content": texto}
        ],
        "do_sample": False,           # Determinístico
        "temperature": 0,             # Mais determinístico
        "max_tokens": 600,            # Máximo de tokens
        "model": "maritalk",          # Modelo padrão
        "repetition_penalty": 1.2     # Penalidade de repetição
    }

    resposta = requests.post(URL, headers=HEADERS, json=data)

    if resposta.status_code == 429:
        print("Rate limited, tente novamente em breve.")
        return None

    elif resposta.status_code == 200:
        return resposta.json()['answer']

    else:
        print(f"Erro na requisição: {resposta.status_code} - {resposta.text}")
        return None

# Classificar cada tweet
resultados = []

for tweet in dados_preprocessados:
    resultado = classificar_texto(tweet)
    print(tweet)
    print(resultado + '\n')
    if resultado:
        resultados.append(resultado)
    time.sleep(5)  # delay de 5 segundos entre as requisições

# Salvar resultados
dados['Classificação_MariTalk'] = resultados
dados.to_csv('/content/drive/MyDrive/Colab Notebooks/2023/BRACIS_toxic/data/resultados_classificacao_maritaca_ToldBR_prompt_1.csv', index=False)
print("Classificação concluída e resultados salvos.")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Não.
#
# rt @user hj é o dia internacional da cerveja e eu acho essa data + importante q meu aniversário e me sinto na obrigação de comemora-l…
# Não.
#
# quatrocentos e dois #mpn #tazercraft
# Não.
#
# sensação horrível puta merda
# Não.
#
# @user caralho casquei kkkkkkkk
# Não.
#
# @user kkkkkkkkkkkkkkkkkkkkk caralho. vou roubar
# Não.
#
# @user Quanto não deve ter sido pago por esse mural??😆😂🤣🤣 Pai amado, é feio mesmo, dou toda a razão de sua insatisfação!🤦🏻‍♀️🙈🙊🤣🤣🤣Qual o artista?😯😳😬🤣🤣🤣🤣
# Não.
#
# o bts, um dos grupos mais famosos mundialmente, fez uma propaganda de maquiagem, USANDO a maquiagem. tem noção da importância disso? eles mandaram a masculinidade toxica ir se foder e tão basicamente mostrando que qualquer um pode usar maquiagem, que não tem gênero... mano
# Não.
#
# o problema n é ser branco mas um racista fdp e racista tem q morrer queimado🔥🔥🔥
# Sim, considero esse texto tóxico. Ele promove a violência e a discriminação com base na cor da pele, o que é inaceitável em qualquer contexto. Além disso, a ameaça de morte é uma violação da lei e dos direitos humanos. É importante respeitar as diferenças e promover a tolerância e o diálogo em vez de incitar a violência e o ódio.
#
# minha mãe tá muito agressiva hj,tudo que eu falo com ela,ela manda eu tnc ,agressividade do crlh
# Não.
#
# @user mulher linda do inferno pqp
# Não.
#
# a mãe n sabe conversa cara, ela só sabe gritar vsf
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e desrespeitosa, além de não contribuir de forma construtiva para a conversa. Esse tipo de discurso pode ser prejudicial para o bem-estar emocional e psicológico de quem o recebe e pode promover um ambiente tóxico e hostil.
#
# eu sinceramente amo minha amizade com a Tatiele, a gente se caga rindo de coisas idiotas, temos piadas internas, conversamos sobre coisas sérias e de quebra somos mãe uma da outra te amo desgraça @user
# Não.
#
# performer da nação caralho
# Não.
#
# queria ganhar mimos da oh, boy!
# Não.
#
# batemos os 150!!! 茅 hoje!!! #stfvergonhanacional
# Não.
#
# rt @user coisa de outro mundo vsf 😩🤤
# Não.
#
# #voleinaglobo eu dou moral dms pra essas meninas, principalmente pra gabi que eu pago pau pra essa menina
# Sim, considero esse texto tóxico. Ele faz uso de linguagem vulgar e inapropriada para se referir a uma pessoa específica, além de conter uma declaração de interesse romântico/sexual que pode ser interpretada como assedio. Esse tipo de conteúdo pode ser ofensivo e desrespeitoso, e não é adequado para ser compartilhado em uma rede social.
#
# finalmente brasil virou esse jogo, pqp
# Não.
#
# eu olho isso me dá um ódio cara que vontade de acabar com a humanidade de uma vez bando de filho da puta desgraçado se eu pegasse faria pior nao adianta só mulher presta mesmo e não é meme
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e discriminatória, além de promover a violência e a misantropia. Esse tipo de conteúdo pode ser prejudicial para a saúde mental e o bem-estar das pessoas expostas a ele.
#
# @user para de mentir pra mim sua gostosa zoiuda do caralho que eu amo
# Não.
#
# @user fala ñ, só vem 😂♥️
# Não.
#
# E o Alexis Mac Allister, do Boca, que tapa o n煤mero 17 no cal莽茫o do Wanchope 脕bila em TODAS as fotos posadas do time? Supostamente o n煤mero 17 est谩 associado 脿 morte e 脿 desgra莽a e o bicho 茅 supersticioso.
# Não.
#
# Millennials descobriam o motel mas não sabem pra que serve. Parece a cena inicial do 2001 lá com os macacos vendo o obelisco
# Não.
#
# nx zero era bom demais pqp
# Não.
#
# a casa da madu é pertin, mas caralho mt coragem sair nesse frio
# Não.
#
# pelo amor de deus que nervoso do carlos falando em inglês o programa inteiro. pqp em
# Não.
#
# rt @user se algum professor noiado chegar e falar ent茫o gente eu quero um trabalho- eu n茫o respondo por mim
# Não.
#
# rt @user escutando antes que vire modinha 🙄
# Não.
#
# ela quer que puxe o cabelo pede tapa na bunda totalmente selvagem eu adoro essa puta🎶
# Não.
#
# sou branco mas tenho vergonha da minha raça pqp
# Não.
#
# o grupo manas 🌻💛 é o melhor do mundo, q q isso irmao
# Não.
#
# foi-se o tempo que eu acreditava em você é o motivo da minha doença mental e ficava mal com isso a ponto de me achar um lixo em saber que eu faço tão mal a alguém que eu sempre amei
# Não.
#
# porque é que são sempre as mais giras que dizem isto :((
# Não.
#
# e eu que tô indo agora para casa mas não lembro onde pego o outro ônibus
# Não.
#
# craque da rodada domingo, classificação heróica na quarta e hoje esse presentão. que semana pro rafinha 👏🔴⚫💪
# Não.
#
# odeio ficar no vácuo, pqp
# Não.
#
# Advogados do m煤sico fuzilado pelo ex茅rcito pedem indeniza莽茫o na Justi莽a Federal. A fam铆lia afirmou que as autoridades nunca prestaram nenhuma assist锚ncia aos envolvidos. Sogro tb foi ferido na a莽茫o #80Tiros
# Não.
#
# 🍻🎊 Dia 10 de AGOSTO tem ALOHA !!🎊🍻 🚺0800 MULHER( até 18 hrs ) 🚹5$ HOMEM( até 18 hrs ) Top Djs : Dj Denilson do Chapadão Dj Juninho da vintém Dj 2g Dj Biel do Furduncinho Dj Jotacê do Salgueiro +tops DJs Local : piscina do bangu @user
# Não.
#
# rt @user olha o preço do x-tudo + batata + guaravitta pqp 7 conto 7 contooooooooooooooo
# Não.
#
# Às vezes queremos que Deus mude as coisas e resolva nossos problemas, mas não queremos conversar com Ele sobre, achamos que Deus tem que fazer simplesmente porque é Pai e sabe da nossa necessidade. Deus quer que nos relacionamos com Ele, nos acheguemos, Ele sente saudade.🙏❤️
# Não.
#
# @user e eu te pergunto: tá errado de bater no retardado? não tá.
# Não.
#
# ta to gostando de b99 que porra 茅 essa.
# Não.
#
# rt @user pior coisa é homem escroto, ó raça fdp
# Não.
#
# vai tomar no cu que coisa linda
# Não.
#
# decisiva pra caralho
# Não.
#
# rt @user tomara que esse mes passe voando 🙏🏻
# Não.
#
# cara do céu vai tomar no meio do cu
# Não.
#
# “mina está lutando contra extrema ansiedade e insegurança. nenhum diagnóstico foi concluído ainda, mas estamos consultando profissionais para tal”
# Não.
#
# rt @user quando um maluco que eu nem conheço fica me olhando de cara feia
# Não.
#
# se quer blz otimo eh nois nao quer tchau e por gentileza va toma no cu
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e desrespeitosa que não é apropriada em um contexto social. Além disso, ele não contribui de forma construtiva para a conversa ou discussão em questão.
#
# #STFVergonhaNacional COMPARTILHEM...DIVULGUEM. LEI ANTI CRIMES JÁ. LAVA TOGA JÁ. REFORMA TRIBUTÁRIA JÁ. CHEGA DE CORRUPÇÃO. CHEGA DE ROUBALHEIRAS. FORA TOFFOLI FORA GILMAR MENDES FORA ALEXANDRE DE MORAES FORA LEWANDOWSKI FORA MARCO AURÉLIO FORA CELSO DE MELLO FORA ROSA WEBER
# Não.
#
# não aguento mais o papai reclamando de tudo quando chega em casa pqp
# Não.
#
# um namorado para me vir fazer companhia aqui a casa 馃槴
# Não.
#
# @user @user isso sim é rola !
# Não.
#
# rt @user isso a globo lixo não mostra...... 🇧🇷#stfvergonhanacional
# Não.
#
# sofro nas mãos do meu novivo puto e meu filho que só sabe rir de mim
# Não.
#
# rt @user kkkkk tão ridículo
# Não.
#
# como eu fui me apaixonar p alguem tao filha da puta
# Sim, considero esse texto tóxico.
#
# @user que lugar da vila olímpia??
# Não.
#
# seria uma honra descobrir — ihhh rapa, não vai rola 😐
# Não.
#
# rt @user mano mo trampo pra quebra um ovo, aprende a quebra ovo carai
# Não.
#
# @user n aceita desculpa desse fodido n, se fez merda uma vez é dar segunda chance pra fazer merda dnv
# Não.
#
# @user o brasil esta podre!! esta mulher 茅 a pior procuradora geral at茅 hoje!!
# Não.
#
# arábia saudita passa a permitir que mulheres viajem sem autorização masculina
# Não.
#
# era depressivo pra caralho, isolado e só tinha contato com o próprio irmão porque a família dele o negava, passou 37 anos entrando e saindo de hospício, cortou parte da própria orelha por ser emocionalmente instável e cometeu suicídio pra vir o jovem 129 anos depois e romantizar
# Não.
#
# eu sempre sou o que gasta mais pqp
# Não.
#
# qual parte de o planeta Terra tá morrendo vcs não entendem? porra para de jogar lixo no chão, para de usar um copo diferente toda vez que você for beber água, para de jogar lixo no mar, para de ser essa pessoa horrível que vai deixar um lugar inabitável para se morar daq uns anos
# Não.
#
# @user A primeira edição, focada nas brasileiras convocadas para a Copa do Mundo, foi um sucesso. Os perfis criados e editados tiveram quase 1,7 milhões de visualizações. A ideia dessa segunda edição é focar nas atletas campeãs brasileiras de 2018. QUEM VAMOS?
# Não.
#
# @user olha o meu tt o pau no cu
# Não.
#
# a única foto que tirei em curitiba foi com a galera do beto, que aquele eno desgraçado postou no face
# Não.
#
# @user vai pra casa do caralho então, ernesto! vai te catar arrombado de merda
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e agressiva, além de não contribuir de forma construtiva para a discussão ou o debate de ideias. Esse tipo de discurso pode ser prejudicial para a saúde mental e o bem-estar das pessoas envolvidas, além de criar um ambiente hostil e desrespeitoso.
#
# tudo isso pra quebra a porra dum ovo?
# Não.
#
# kkk parece alguém que eu conheço
# Não.
#
# enjuriado slc semanais lixo kk
# Não.
#
# aooooo to boladao nessa porra pprt
# Não.
#
# acabei de fazer o maior trabalho braçal da minha vida, to morta
# Não.
#
# NÃO É MACHISMO Fale o que quiser o que é é Verme ou sangue bom, tanto faz pra mulher Não importa de onde vem nem pra que Se oque ela quer mesmo é sensação de poder 🎧
# Não.
#
# @user n ganha a olimpíada nem fudendk, vao tomar um pau se continuar desse jeito
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e agressiva, além de promover a violência e o ódio. Esse tipo de discurso não é aceitável em um ambiente saudável e respeitoso.
#
# @user seu nome está nos prints do pavão. melhor ficar quieta!!
# Não.
#
# quem fez esse vídeo tá de para béns
# Não.
#
# rt @user @user ta ai um mulherão da porra
# Não.
#
# @user vai toma no seu cu...
# Não.
#
# Olha,só queria te dizer q vc é insuportavél,implicante,grosso,muitas vezes babaca mas eu n queria q vc mudasse absolutamente nadaa. Te amo desse jeitinho..feliz aniversario meu bebê❤️ Que papai do céu continue abençoando vc e sua familia sempre. RAMONZIN EU VOU COMER TEU BOLO🎂
# Não.
#
# Essa é a minha intenção! Nao vou me desgastar com toda a negatividade da tl,só aceitei e pronto, todo mundo canta bem e dança bem então eu espero o melhor deles
# Não.
#
# @user @user acho que você já viu os vídeos, né greg? ou seja, foi lacrar e se fodeu
# Não.
#
# @user @user pqp, tu é linda pra cacete!
# Não.
#
# @user @user vai fica falando bota ah cara porra tá facinho seus cuzão 🐊🐇👑✂️🇮🇱👌
# Não.
#
# rt @user só eu posso, se fizerem do meu lado eu me irrito
# Não.
#
# rt @user chorando vendo filme de sapatao sonhando com um dia que eu vou ter um romance clichê
# Não.
#
# @user fala fdp
# Não.
#
# dando oq recebo
# Não.
#
# PARABÉNS EXCELENTÍSSIMO CIDADÃO PATRIOTA SÉRGIO MORO ! SE FOR CANDIDATO NA PRÓXIMA ELEIÇÃO PARA PRESIDENTE DA REPÚBLICA, MEU VOTO É SEU.
# Não.
#
# @user fofoqueira
# Não.
#
# algo despertou o homem hétero cis q habita em mim pois eu ando pensando: e se eu trovasse essa guria de 17 anos? tá quase c 18 né...
# Não.
#
# o numero 1 é o fato de eu ter q ir nesse sol do caraio comprar oito quilos de areia, abençoa deux
# Não.
#
# queria estar nesse episódio da grande família que a marilda vai num grupo de apoio que chama mulheres que amam errado
# Não.
#
# @user simmmmm pqp
# Não.
#
# rt @user música antiga do meus vídeos e camiseta do over the garden wall asdaushdhusadh caralho
# Não.
#
# vídeos que eu amo assistir na internet: racistas apanhando feio em qualquer região do planeta
# Não.
#
# @user @user mano acho que vou entrar no Procon ou com processo pq isso é fazer o consumidor de otário, paguei caro pra ele ficar mais no concerto do q comigo pqp
# Não.
#
# @user @user Sabe oq é bom disso, que a mídia com essas picuinhas, vai fazer o Bolsonaro ganhar todas as eleições e deixar caminho aberto pra quem ele indicar. O povo não cai mais nessas lorotas.
# Não.
#
# tá triste pq brigou com o crush? — kkkkk não briguei com crush! to triste por outros motivos
# Não.
#
# @user vou te fuder em
# Não.
#
# rt @user queria vencer na vida de f茫 igual a maisa venceu #mpn #luansantana #luanetes #luansantanashow
# Não.
#
# rt @user nao vai ter eu passando no vestibular esse ano
# Não.
#
# o universo sabe exatamente oq está fazendo
# Não.
#
# como que a cnb perdeu esssa partida man que cblol é esse pqp
# Não.
#
# vai se fuder eu li calcinha kkkkkkkkkkkkkkk
# Não.
#
# @user @user 😂😂😂😂mais nao tinha falado ontem que não ia ser patrocinado nada que pudesse violar a moralidade da família brasileira 🤦‍♂️
# Não.
#
# mano essa musica da vontade de se apaixonar pqp
# Não.
#
# ultima vez q tive q ir pro hospital tinha um cara louco la eu la tomando soro e ele me olhando feio e brigando com as moça de la eu fiquei com muito medo ele me olhou com ODIO. o cara tava cheio de odio no coraçao
# Sim, considero esse texto tóxico. Ele descreve uma situação de violência e hostilidade, e o uso de letras maiúsculas e palavras como "ódio" e "brigando" dão a impressão de que a pessoa está tentando incitar emoções negativas nos leitores. Além disso, o texto não apresenta nenhum tipo de contexto ou explicação para a situação descrita, o que pode levar a interpretações erradas e potencialmente prejudiciais.
#
# @user @user @user @user Então proíbe as grandes indústrias de produzir qualquer coisa, pois são essas que fazem as piores coisas para o meio ambiente, a porra de um cara fazendo temaki no copo não faz o impacto de um celular pra ser produzido, dps descartado na natureza
# Não.
#
# @user sulista = aberração
# Não.
#
# ciência brasileira ameaçada!
# Não.
#
# furei a sombrancelha amo??????? pqp mais linda nao existe
# Não.
#
# @user pode é melhorar😁
# Não.
#
# rt @user porra vou fzr 16 anos e ate agr n fiquei bonito
# Não.
#
# vou comprar um exemplar para colocar lá no banheiro da rodoviária, caso acabei o papel higiênico.
# Não.
#
# me racho d rir com o marcelo pqp
# Não.
#
# @user @user @user é mônica, nenhuma surpresa, tudo uma lamaceira só... quanto mais mexe...
# Não.
#
# que ódio disso snrs
# Não.
#
# naruto ou sasuke? — porra de anime todo dia isso maluco se fude
# Sim, considero esse texto tóxico.
#
# olha isso...🤦🏻‍♂️💢 é na cara de pau
# Não.
#
# crlh, odeio n poder fazer trabalho c indicação alta irmão, é uma coisa q me deixa puto 😴😴😴😴
# Não.
#
# maior dupla de zaga da am茅rica n茅 馃
# Não.
#
# @user @user chega de farra com o dinheiro do povo. FUNDO ELEITORAL NÃO Não é de interesse do país, não é necessidade. Só serve pra agradar político bandido e partido quadrilha.
# Não.
#
# Minha conta iria fazer 10 anos, em abril perdeu todos os seguidores, recomeçando, foi suspensa dia 25 de julho. Enquanto do outro lado, o da criminalidade, pode todos os absurdos, o Povo honesto e trabalhador não pode nada. Não seremos adestrados. Nunca! #DireitaCensurada
# Não.
#
# @user Vamos aguardar o laudo do Instituto Nacional de Criminalística da Polícia Federal. Tem muito material a ser examinado, muitas trocas de mensagens, muitas transferências financeiras, muitas maracutaias.
# Não.
#
# eu falo que quero gira de exu todo momento, mas quando tem a dona mulambo me d谩 cada castigo diferente que pqp. cada dia um tombinho bom!
# Não.
#
# @user porra, aí é foda
# Não.
#
# desde cedo na rua resolvendo as coisas, só queria praiar ou pega um solzinho da laje mesmo
# Não.
#
# @user com o andré te levando nas costas kkkkk tu encomoda mais do que um caminhão de macaco kkkkkkkkkkkkkkk
# Não.
#
# rt @user essa musica arrepia até meu cu
# Não.
#
# pooo com deus ent茫o鉂わ笍
# Não.
#
# lavei meu tênis com maior cuidado e amor do mundo p vim uma desgraçada e pisaaaar
# Não.
#
# mantra do dia: pau no seu cu e foda-se
# Não.
#
# enquanto cuidam da minha vida, eu cuido do meu coração. #sextaligadajustiçasdv
# Não.
#
# Sem a possibilidade de ser um pouco mais suave com uma caralhada de pessoas porque 茅 s贸 abaixar a guarda, que as pessoas se sentem no direito de serem um lixo. Infelizmente, tenho que manter o chumbo grosso o tempo todo.
# Não.
#
# @user você não conhecia o ministro da saúde mesmo. ele é um amontoado de polêmicas vazias que acertou nesse projeto dos médicos.
# Não.
#
# que desgraçado cara
# Não.
#
# lidar com mulher não é fácil, porém amo kkkk
# Não.
#
# vai tomar no cu nao sei fazer nada só quero morrer logo
# Sim, considero esse texto tóxico.
#
# @user não esquece desta, canalha:
# Não.
#
# rt @user 馃惃 army segue army 馃惃 鈫琭avorite para ganhar seguidores armys. 鈫瑀etweet para que mais armys possam participar.
# Não.
#
# rt @user perguntar o que a pessoa tá fazendo é o auge de sem assunto
# Não.
#
# meu deus que inferno de frio de novo vtnc
# Não.
#
# rt @user precisamos ajudar. por favor, sigam @user
# Não.
#
# rt @user eu depois de tentar estudar e não entender nada.
# Não.
#
# sei la velho aprendam a lidar com a porra das consequencias dos teus atos sabe eu to revoltada com isso ate agora
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e inapropriada, além de ser desrespeitoso com o interlocutor.
#
# essa porca kkkkkkkkkkk
# Não.
#
# isso não significa nada não sei pq estou suando
# Não.
#
# @user porra, nem fala, fica impossível sair da cama
# Não.
#
# esse maluco é pica demais kkkkkkkk
# Não.
#
# cada bosta que eu falo alguem me para velho ridicula demais aaaaaaaaaaaaaaaaaaaaaa
# Não.
#
# mas é óbvio oq vc esperava
# Não.
#
# bah meu, olha a declaração do deco nascimento pra imprensa. tem o quê na cabeça um abobado desses pra falar isso? pqp....
# Não.
#
# que absurdo.
# Não.
#
# @user @user Eu sou responsável pelo o que eu escrevo, não pelo o que você entende! Em momento algum na postagem eu citei que usufruíria da promoção hoje.
# Não.
#
# Deslize as fotos para ver um pedacinho do paraíso . Fazenda histórica em meio à natureza, ouvindo o canto dos pássaros e conhecendo a História do ciclo do café. . . . #valedocafé #fazendaunião #hotelfazendaunião…
# Não.
#
# @user @user @user @user porra , que ministro foda, tem de ficar uns 10 anos, vai asfaltar o atlantico
# Não.
#
# que susto do caralho, sou míope mano, para conseguir ver que tinha uma frase em baixo foram 10 colapsos
# Não.
#
# Desculpa, mas não dá pra defender um festival com tanta viadagem assim Não pode água, não pode comida, não pode câmera profissional, não pode cooler, porra Eu tava afim desde o início do ano, até ver as frescuras
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e discriminatória em relação a comunidade LGBTQ+, além de ser desrespeitoso com os organizadores do festival e com os participantes que tiveram suas expectativas frustradas.
#
# @user @user kkkkkkkkkk eu entendi idiota
# Não.
#
# @user @user @user preocupado com o vasco, amigo?
# Não.
#
# @user parab茅ns 鉂わ笍
# Não.
#
# ela faz isso todo fds
# Não.
#
# [3/8 12:12] vitória brandão: aí amor o auge meu contato princesa HEUEHEUHEUEH [3/8 12:12] piece of sky 💜: vou colocar [3/8 12:12] piece of sky 💜: idiota do caralho bom dia KKKKKKKKKKKKKK
# Não.
#
# @user @user Mas a vaca comunista é muito engraçada hein? Não não! Não posso te chamar de vaca. Em pais socialista não tem carne pro povo! Então fica de lixo socialista mesmo. Bom é governo sanguinário que passa pano pra 70 mil assassinatos. Se acontecer algo liga pra PM opressora sua imunda!
# Não.
#
# pablo é mt filho da puta cr, que isso 🤬🤯
# Sim, considero esse texto tóxico. Ele contém ofensas e palavrões que são inapropriados e desrespeitosos. Além disso, o uso de palavrões e ofensas não contribui para uma discussão construtiva e respeitosa.
#
# muita gente falando “só observo” e esquece de olhar pra dentro de si mesmo e ver o lixo de ser que é.
# Não.
#
# shawn só recebe mais biscoito porque faz pop e o harry não, se o harry fosse pro pop baladinha também o mundo inteiro lambia o cu dele igual lambem o do shawn assim como lambiam quando ele era da one direction kkkk agora falar que ele é mais talentoso que o shawn KKKK
# Sim, considero esse texto tóxico. Ele faz uso de linguagem ofensiva e comparativa para desmerecer a habilidade de um artista em relação ao outro. Além disso, ele também utiliza uma analogia inapropriada para expressar a opinião sobre os fãs dos artistas mencionados.
#
# todo dia um cis passando vergonha comentando não parece que é trans ou não tem uma aparência trans vai tomar no cu inferno
# Não.
#
# @user PEÇONHENTA, de onde é a fonte? Kkkkk para que tá feio! Essa Pati, foi diagnosticada lOKKA por uma Psiquiatra. Por falar nisso? O falso neném dela tá bem? Dupla sertaneja! PEÇONHENTA e NOCIVA! Já em cartaz! Vamos #DireitaUnida?
# Não.
#
# Mas meu tio pqp, 15 minutos com ele no carro e eu dei umas 3 freadas bruscas só pra ele calar a boca, o cara só dirige moto e não sabe nada de carro e fica querendo mandar no que eu vou fazer, aí meu cu, da próxima eu pago um uber pra ele
# Não.
#
# esse pessoal de esquerda gostam de falar asneiras
# Não.
#
# rt @user vamos pra tóquio cacete pq fas iso cmg brasil #voleinaglobo
# Não.
#
# @user hm ridículo
# Não.
#
# @user mudamos puto kkkk
# Não.
#
# parece aquelas minhoca de maçã
# Não.
#
# acabou de publicar uma foto
# Não é possível determinar se um texto é tóxico ou não sem mais informações sobre o contexto em que ele foi publicado. A definição de "tóxico" pode variar dependendo do contexto e das intenções do autor. Além disso, a análise de texto não é uma tarefa simples e exige uma compreensão completa do contexto e do propósito da comunicação.
#
# rt @user amiga é o caralho,amiga de cu é rola
# Não.
#
# Passou muito dos limites. Essa quadrilha do stf tem que ser tirados se n茫o for por bem vai por mau mesmo. Filhos da puta.
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e ameaçadora, além de promover a violência contra um grupo de pessoas específicas. Esse tipo de discurso pode incitar comportamentos violentos e prejudiciais à sociedade.
#
# oi gente manda pergunta ai
# Não.
#
# @user nem meme, da uma agonia do caralho
# Não.
#
# @user @user ele provou. chora, petista.
# Não.
#
# vontade nemhuma de levantar da cama, pqp
# Não.
#
# @user anão
# Não.
#
# rt @user foda que ela é linda e eu apenas sulista dançando brega funk
# Não.
#
# ano que vem o pau quebra, meta ser o 01
# Não.
#
# comecei a assistir vikings,pqp é muito bom
# Não.
#
# rt @user gente vcs são burros, da pra perceber nitidamente que ela tá flnd com ironia
# Não.
#
# minha dermatite at贸pica atacou, fui co莽ar a perna e abri 50% da minha perna agora t谩 tudo sangrando eu n茫o aguento mais essa doen莽a fudida
# Não.
#
# @user a pf quando deflagra uma operação para prender hacker , legitima ainda mais as informações.
# Não.
#
# se essa conta floppar a gente finge que não aconteceu
# Não.
#
# o que fizeram com a fla tv? que coisa ruim!
# Não.
#
# glenn passa muito bem, né? david miranda é muito gostoso pqp com todo respeito ao gleen
# Não.
#
# Fáltame moito para chegar a ter fillos, pero as historias que xiran arredor desta temática introducen reflexións e inquedanzas sobre as limitacións da esfera doméstica, a metamorfose do corpo e o cambio nas relacións interpersoais (+)
# Não.
#
# isso caralhooooo vira essa porra nem que seja na força do ódio
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e inapropriada, além de promover uma atitude agressiva e violenta. Esse tipo de discurso pode ser prejudicial para o bem-estar de outras pessoas e não é aceitável em um ambiente saudável e respeitoso.
#
# @user @user rainha da porra toda 😎 #macabeso #barbaralopeztrendy #santiagoachagatrendy #kcmexico
# Não.
#
# rt @user mama a tia? pode por seu pau no meio tb, garanto que são bem macios! hehe não esquece de compartilhar a fotinho ta?
# Não.
#
# o lado bom de só sua mãe se preocupar com você é que não rola falsidade pelo menos!!!
# Não.
#
# 💙 Vamos ajudar a irmandade a aumentar seus seguidores?💚 💛 Direita unida. Apoiando o governo por um país melhor para todos 👉🇧🇷💚 1. Vc me segue 2. Eu sigo vc 3. Deixe seu @user 4. SDV todos que ti seguirem 5. RT e curta 🔃RT 🔃 RT. Vamos interagir?? 🇧🇷SE SINTA ESPECIAL HOJE
# Não.
#
# mais sonsa que a minha mãe só duas dela, ela fez eu postar foto dela no facebook e fez a kátia cega no comentário kkkkkkkkkkkkkkk q odio
# Não.
#
# @user machista fudido
# Não.
#
# iiiii ,foi apenas curiosidade eu não quero nada contigo ridículo — ou seja, zé porva. vai toma no cu
# Não.
#
# @user @user opa opa opa parece um convite irrecusável
# Não.
#
# rt @user agora a meta é pau na xrc #adf
# Não.
#
# eu n茫o sabia que ela tinha morrido e n茫o sabia que era ela no filme t么 chocada
# Não.
#
# caraaaalho namoral que susto pohaaaa, eu tava assistindo um negócio da annabelle 3 e mainha falou saaaaaa pqp irmões o pulo que eu dei
# Não.
#
# rt @user sinto cheiro de jungkook usando o cabelo amarrado logo logo, hmmmm
# Não.
#
# nunca mais quero namorar vsf eu perco o interesse em todo mundo
# Não.
#
# @user chegou a hora. @user #correverdevaldo
# Não.
#
# eu e meu primo reproduzindo cenas de a fazenda .. tudo ! ai como eh bom ter parente viadinho
# Não.
#
# caralho velho, manda mensagem e espera q eu respondo, não me liga q eu não vou atender
# Não.
#
# doida pra ver josiane tomando um pau mais tarde 😉
# Não.
#
# amava a juliet em grimm at茅 metade da 4 temporada, vai pra pqp quem gostar dela dps do que ela fez n茫o 茅 normal
# Não.
#
# @user estou em campanha o tempo todo seu blogueiro invejoso 👍🏻 e o mula vai continuar preso 🤣🤣🤣
# Não.
#
# vai dar tudo certo
# Não.
#
# to puto q essa luz não volta, to doido pra cortar o cabelo
# Não.
#
# de repente você chega revirando a minha vida cheia de amor pra dá, pra falar de sentimento que até bem pouco tempo você quis me bagunçar... 🎶
# Não.
#
# caralho, eu vou matar a jeniffer
# Sim, esse texto é tóxico.
#
# Precisamos pensar em coleta seletiva e por em prática lei de resíduos sólidos. #preservacaoambiental #salveoplaneta #universidadedeaveiro #aveiro #Portugal em Universidade de Aveiro
# Não.
#
# #Intervozes | Uso de canais de comunica莽茫o p煤blica para propaganda e comunica莽茫o estatal 茅 inconstitucional, apontam procuradores na a莽茫o.
# Não.
#
# tô c tanta vergonha, queria conseguir me abrir sobre isso, mas falta coragem
# Não.
#
# rt @user eu n esperava nada desse show mas pqp pq tão perfeitos😻
# Não.
#
# eu tenho medo de esperar e nada acontecer.
# Não.
#
# sim caralho esse é o tweet!
# Não, eu não considero esse texto tóxico. Ele pode ser considerado ofensivo ou inapropriado em algumas situações, mas não é tóxico.
#
# @user chora comunista miserável 😡👎🏼⚡ #falamaisbolsonaro que tá pouco.
# Sim, considero esse texto tóxico. Ele contém ofensas e insultos direcionados a um indivíduo com base em suas crenças políticas, além de promover um discurso de ódio e intolerância. Esse tipo de discurso é prejudicial para a construção de um ambiente saudável e respeitoso de discussão de ideias e opiniões.
#
# @user rapaz esse pessoal tá demais hein, pqp
# Não.
#
# o jeito q minha mae mima mais o gato do q eu é surpreendente
# Não.
#
# @user o mais engra莽ado ainda 茅 que tem gente que tipo, usa mesmo
# Não.
#
# saudades quando nas férias eu dormia o dia todo, agora é um b.o. diferente todo dia
# Não.
#
# saudades ser a maldita de 3 meses atr谩s
# Não.
#
# deve ser muito estranho transar com camisinha néon a gente lá no ato e olha pro meninão ele lá brilhando mais que a ariana grande
# Sim, considero esse texto tóxico. Ele faz uma analogia inapropriada e desrespeitosa com o uso de preservativos e Ariana Grande. Além disso, usa uma linguagem vulgar e desrespeitosa em relação às mulheres.
#
# rt @user porra vai se fuder, deus tira esse sentimento d mim por favor, n aguento mais ficar mal por isso
# Não.
#
# queria fazer um desse mas tenha um total de 0 coment谩rios af
# Não.
#
# @user final de tvd acabou cmg pqp xxx
# Não.
#
# caralho, eu só sei dormir
# Não.
#
# mãe eu te amo pra um caralho
# Não.
#
# eu já conheci gente do twitter que me interessei, obvio. mas mora longe p porra maior palhaçada isso
# Não.
#
# pessoal do iesb em dias pares finjam que não me conhecem ok pois vou ser mais feia que o normal nos dias impares podem cumprimentar
# Não.
#
# puts minha tia começou a gritar comigo aqui igual retardada minha vontade era gritar de volta mas fiz melhor e só fiquei quieta e deixei gritar sozinha igual doida
# Não.
#
# rt @user na moral, quer assunto cmg????? chega já zoando to cnsd de responder “oi, tudo bem?”
# Não.
#
# fico puta com essas graças 😤
# Não.
#
# Os detalhes a serem trabalhados antes do acordo ser fechado estão relacionados aos direitos de imagem e alguns detalhes técnicos, como as taxas de câmbio, e o fato de o United ter acabado de fechar com Maguire. [@user
# Não.
#
# trabalhei passando mal p caralho tnc
# Não.
#
# rt @user família é quem fecha, meu sangue até mosquito tem
# Não.
#
# chego nesse site e ainda tem gringa puta com o sexiest moment kkkkkkkk tao ofendendo até o bob, q coisa né
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e discriminatória em relação a mulheres, além de ser desrespeitoso com os usuários da rede social.
#
# @user @user @user olha você suas #,não tem nem vergonha né gado!
# Não.
#
# e olha que eles nem debutaram lendas aclamadas demais pqp
# Não.
#
# mano q odio q eu tenho quando quero ficar com uma pessoa ai ela vai e fica com outra pq tipo, ta no direito dela né, ela nem sabe oq eu quero, ai eu vou e fico puta com isso ao mesmo tempo em q sei q é errado e babaca, não consigo evitar
# Não.
#
# rt @user a palavra de deus está toda aqui pqp que hino
# Não.
#
# rt @user vai tomar no cu não consigo ver vídeo de jogo que tem jump scare, mesmo sabendo que vai dar susto, eu quase morro
# Não.
#
# @user - primeira impressão: meu deus q linda - nível de proximidade: 10 - gosto de você: sim, muito - considero: meu porto seguro - onde conheci: no seu aniversário - pra ser honesto: eu te amo p um caralho, você é o amor da minha vida e só tenho que agradecer
# Não.
#
# rt @user passei de manhã e ele ainda estava la kkkkkkk pqp
# Não.
#
# quem fala que tem uma relação puro frufru, tá mentindo.
# Não.
#
# @user @user o petista pare com o choro, seu mestre está na cadeia👏👏
# Não.
#
# @user @user @user @user aqui no sul a imprensa fala em flamengo x palmeiras
# Não.
#
# @user come o cu do polezza
# Não.
#
# ÉPolíticaBrasil entrevista psicopedagoga Deborah Araujo Maia DIA 02/08 - ÉPolíticaBrasil com Miguel Carvalho está imperdível. Vamos entrevistar a alfabetizadora e psicopedagoga Deborah Araujo Maia, num bate-papo…
# Não.
#
# onde tá minha cueca
# Não.
#
# acho engraçado esses macho q a gnt n da chance, eles já logo acham que somos lésbicas, até pq né não existe a opção da gente não querer sabe BANDO DE PAU NO CU
# Não.
#
# @user se eu ficar com shadowban de novo eu vou ficar puto #mpn #nowunited #uniters #marinaruybarbosa
# Não.
#
# rt @user só quem passa por crises de ansiedade sabe a vontade de morrer q a gnt sente
# Não.
#
# nada nothing acontece sem a permiss茫o de deus, e tudo everything que deus permite em nossas vidas tem um prop贸sito. 鉂�
# Não.
#
# @user ain eu quero ainda rola?
# Não.
#
# @user gente, é óbvio que é ironia né pqp
# Não.
#
# dameláaaaaaaaa
# Não.
#
# rt @user sdds do nosso grupo kkkkkkkkkkkkkkkkkkkkk
# Não.
#
# @user @user @user @user Estava a falar do Félix porque é um caso disto mesmo e o tweet inicial era sobre o Félix. Querias que fosse falar do quê? Do Ronaldo?
# Não.
#
# mira lo gorda que estas. me das asco
# Sim, esse texto é tóxico.
#
# rt @user a minha vida tá quase igual a do bolsonaro: é só puta, palhaço, comedor de traveco e atriz decadente me criticando.
# Não.
#
# @user #STFVergonhaNacional COMO PODE UM PAÍS TER UMA CORTE DESSA SÓ SENDO MESMO INDICAÇÃO DO PT ,PSDB,MDB É ISSO QUE DÁ COLOCAR ESSA GENTALHA GENTALHA NO PODER.
# Não.
#
# @user unico momento q dar a opinião vira de fato efetivo kk preciso clikar!!
# Não.
#
# ela dizendo pra cris que só ficou com ela por causa da doença e que não ama a cris joana sua idiota porque você ta fazendo isso?
# Sim, considero esse texto tóxico. Ele contém insultos direcionados a outra pessoa e expressa uma opinião extremamente negativa sobre ela, sem nenhum tipo de fundamento ou argumento válido. Além disso, o uso de palavras ofensivas como "idiota" é inapropriado e desrespeitoso. Esse tipo de linguagem pode ser prejudicial para a pessoa que é alvo dessas ofensas e pode causar danos emocionais e psicológicos.
#
# puta merda pq o povo acha que é legal falar no telefone?
# Não.
#
# @user @user 😂😂😂😂😂😂😂😂 chora mais #bolsonaronabahia
# Não.
#
# almoçar yakisoba é muito bom pqp .. queria poder comer todos os dias...
# Não.
#
# é tudo ou não, caralho!
# Não.
#
# @user o caralho te
# Não.
#
# @user eu odeio esse filho da puta psicopata maldito
# Sim, considero esse texto tóxico.
#
# esse ngc de fé nas malucas mano, só os doentes acham isso certo vai se fuder, bando de menina doente
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e discriminatória, além de promover a exclusão e o ódio em relação a um grupo de pessoas com base em suas crenças religiosas. Esse tipo de discurso é prejudicial e não tem lugar em uma sociedade inclusiva e respeitosa.
#
# deixando pequenas coisas me afetarem como se não houvesse amanhã 🙃😊🥰🙃😍
# Não.
#
# fiquei um preocupada com esse vídeo
# Não.
#
# @user eu sou feio mas queria fazer parte do seu bonde 🤦😏
# Não.
#
# que energia mais punk, pqp
# Não.
#
# a olivia eh perfeita, dá vontade de colar uma foto dela na minha testa
# Não.
#
# rt @user isso não é uma buceta, é um buraco pra outra dimensão 😱
# Não.
#
# porra cansei de ser o troxa q chega nos luga primeiro q os amigo, meu pau
# Sim, considero esse texto tóxico. Ele contém linguagem vulgar e ofensiva, além de ser inapropriado para o contexto de uma rede social.
#
# @user De novo problemático. Não é um público seleto, que entende da mecânica e pode contribuir. Nenhum dos prós (ou produtores de conteúdo) que sigo, por exemplo, já chegou a receber a beta pra testar. Fica complicado
# Não.
#
# não pode mas nem brincar, nesse caralho
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e inapropriada, além de não contribuir de forma construtiva para a conversa ou discussão em questão. Esse tipo de linguagem pode ser prejudicial para o ambiente e para as pessoas envolvidas na conversa.
#
# rt @user é, o povo continua firme no cu... 🤭
# Não.
#
# mano oq as sulistas tem de gata elas tem de mongolóide
# Sim, considero esse texto tóxico. Ele faz uso de ofensas e estereótipos para depreciar uma região e seus habitantes, promovendo a discriminação e a intolerância. Além disso, ele utiliza termos pejorativos e ofensivos para se referir a pessoas com deficiência intelectual, o que é extremamente inapropriado e desrespeitoso.
#
# não lembro da ultima vez que quis tanto abandonar um livro pqp nao e possivel
# Não.
#
# eu no ensino fundamental com bolas de papel e o cesto de lixo
# Não.
#
# dps que tu começa a dirigir a 20km/hr tu acha que todo mundo ta dirigindo igual doido
# Não.
#
# Oi,gente. Esse é o nosso amigo Guilherme. Ele é muitoooo fã do @user e o sonho dele é conhecer ele. Queria a ajuda de vocês para darem rt até chegar no Felipe Neto. bjos
# Não.
#
# e a bilheteria dela nem foi por causa dela
# Não.
#
# banho no gordo
# Não.
#
# @user já bebi um litro de água hoje mo beba tbm se alimente se vc esperar eu chegar vc n vai comer nunca agora vai comer porra
# Não.
#
# charli sempre a frente do seu tempo lançando tendências
# Não.
#
# e no final era só uma pirada
# Não.
#
# odeio a marta , puta que pariu como é que sinto tantas saudades dela 🙃🙃
# Sim, considero esse texto tóxico.
#
# @user @user @user @user Kkkkkkkkkkk a mina usa uma saia da Fendi falsa e sutiã como Cropped e quer Opinar na roupa da mina pqp 🤦🏾‍♂️
# Sim, considero esse texto tóxico. Ele faz uso de ofensas e julgamentos baseados na aparência da pessoa, além de conter misoginia e discurso de ódio.
#
# então assim eu respiro conto até 1000 e continuo todo dia tentando enfiar na minha cabeça que ok tá tudo bem vamo lá vc sai dessa porra
# Não.
#
# rt @user ou você conta ou eu descubro
# Não.
#
# mano meu cabelo é uma mistura man
# Não.
#
# @user um babaca, se achou o fodão mais quando a porta abriu o cu sumiu...
# Sim, considero esse texto tóxico. Ele contém ofensas pessoais e palavrões, além de ser desrespeitoso e agressivo. Esse tipo de linguagem não é apropriada em um contexto social e pode causar danos emocionais e psicológicos à pessoa alvo da ofensa.
#
# @user @user bl谩 bl谩 bl谩.. a terra 茅 quadrada...
# Não.
#
# na proxima temporada do loonareign quero ser um palhaço
# Não.
#
# @user @user quebrou a cara kkkkk
# Não.
#
# @user @user to manca fdp
# Não.
#
# rt @user até agora eu não entendi a graça disso. corpo toda mulher tem.
# Não.
#
# um açaí me deixaria muito feliz hoje
# Não.
#
# que dor de cabeça jamais vista pqp
# Não.
#
# rt @user no ainda temho q corta cabelo hj q buceta
# Não.
#
# acabou de publicar uma foto
# Não é possível determinar se um texto é tóxico ou não sem mais informações sobre o contexto em que ele foi publicado. A definição de "tóxico" pode variar dependendo do contexto e das intenções do autor. Além disso, a análise de texto não é uma tarefa simples e exige uma compreensão completa do contexto e do propósito da comunicação.
#
# @user @user vai ser burro assim lá na casa do chapéu
# Não.
#
# shawn mendes eh homofobico pq ja deixou claro que não eh gay cancelem essa aberração 😡
# Sim, considero esse texto tóxico. Ele faz uso de uma linguagem ofensiva e discriminatória para se referir a Shawn Mendes e sua orientação sexual. Além disso, o texto promove a cancelamento de alguém com base em sua orientação sexual, o que é injusto e prejudicial.
#
# rt @user vamos de uma palavra uma música? #mpn #luansantana #luansantanashow #luanetes
# Não.
#
# @user esse site é um lixo
# Não.
#
# @user @user isso é caso de polícia.
# Não.
#
# se é meu filho perde os dentes na hora
# Não.
#
# é agosto e eu não consigo ir para a praia. isto é ridículo meu
# Não.
#
# estou simplesmente apaixonada pela @user pqp q mulher incrível
# Não.
#
# gente pqp hoje eu descobri que as notificações tem o botão de ver mais
# Não.
#
# só presta a carioca
# Não.
#
# incrível como tem gente que gosta de me tratar como lixo
# Não.
#
# rt @user deve ser triste não me suportar e não poder me chamar de feia né 😚😚😚
# Não.
#
# meu deus mano que menina chata da porra
# Não.
#
# vitao é perfeito mano pqp
# Não.
#
# @user babaca pau mandado!!!!se tivesse o minimo de carater e conhecimento seria contra esse autoritarismo!!!vendido
# Sim, considero esse texto tóxico. Ele contém ofensas pessoais e palavrões, além de promover um discurso de ódio e desrespeito em relação a outras opiniões.
#
# onde eu fiquei totalmente sem a parte de cima kkkkkkkkkkkk
# Não.
#
# essas cores foi as únicas que nunca usei no aparelho. então me ajudem, qual???
# Não.
#
# @user vai ver era so um baiano eles chamam as pessoa de pai dan
# Não.
#
# mano é errado sentir prazer vendo a porrada? caralho
# Não.
#
# @user liga pra samu liga pra samu ela transou com 3 deu hemorragia no cu
# Sim, considero esse texto tóxico. Ele faz uma referência inapropriada e ofensiva a uma pessoa, usando linguagem vulgar e desrespeitosa. Além disso, o conteúdo do texto pode ser considerado como difamação e calúnia, pois ele afirma algo falso e ofensivo sobre uma pessoa sem nenhuma prova ou evidência. Esse tipo de conteúdo é inaceitável e viola as políticas de uso de redes sociais e deve ser denunciado.
#
# se eu vi isso vcs tbm vão ver
# Não.
#
# quantidade de hetero que eu peguei? zero. quantidade de encubados que eu peguei? perdi a conta.
# Não.
#
# @user @user @user Curioso, pq isso cai como uma luva para a doceira plagiadora que por conta do fracasso ta com medo de lançar o 5° album kkkkk
# Não.
#
# a pílula do skylab já me dá o poder de chupar meu próprio pau
# Não.
#
# rt @user ele não perde essa mania, coisa feia cr
# Não.
#
# rt @user 3 palavras: merecem fãs melhores.
# Não.
#
# @user @user eu e ele é dois idiota kkkkkkkkk e olha q eu ainda avisei ele
# Não.
#
# @user @user @user @user porra lara tem q abraçar os gatos
# Não.
#
# Geromel e Kanemann Geromel e Bras Kanemann e Bras Geromel e Paulo Miranda Geromel e Rodrigues Kanemann e Rodrigues Kanemann e Paulo Miranda Bras e Paulo Miranda Rodrigues e Paulo Miranda Geromel sozinho com outro zagueiro expulso. 10 t谩 bom por agora..
# Não.
#
# quando eu comprar um desses eu vou ficar nojenta
# Não.
#
# como existe gente idiota na vida tnc
# Não.
#
# @user exatamente
# Não.
#
# trajado de sufgang assim que elas gosta
# Não.
#
# tão óbvio que o yug acharia todos, eu não achei nenhum sgyuasuyags
# Não.
#
# cade bomba patch no 360 porra eu la quero saber de daniel alves
# Não.
#
# @user duvivier kkkkk ninguém conhece vc, trouxa PTralha 👉🏼💩! Os Paraíbas e o Brasil amam o Mito @user É o fim do PT e da boquinha do tal duvivier @user @user @user @user RT @user @user Baiano é inteligente 🧠👍🏼
# Não.
#
# rt @user @user irmã querida, orgulho.. parabéns 😍
# Não.
#
# make feita por mim 🥰
# Não.
#
# eu DESISTO de cantar zimbra o tom de voz das músicas ACABA COM A MINHA GARGANTA ou é muito baixo, ou é muito alto, ou tem uma técnica vocal do caralho QUE EU NÃO SEI USAR EU CONSIGO CANTAR >TAKE ME TO CHURCH< MAS NÃO CONSIGO CANTAR >VIVA< olha sinceramente...
# Não.
#
# menino é um bicho burro né mesmo? é só se aproximar que eles já acham q tu quer alguma coisa a mais... orra
# Não.
#
# rt @user pqp, a josefine é muito linda.
# Não.
#
# eu nn aguento cara as rua daqui parec um cu prolapsado
# Sim, considero esse texto tóxico.
#
# ta agora eu preciso de ajuda eu arrumei minha estante e ficou assim ne MAS eu preciso colocar esses cds em algum lugar vcs acham que iria ficar muito feio se eu colocasse em cima de alguns livros¿?
# Não.
#
# rt @user fico puta quando vou stalkear alguém é só tem meme
# Não.
#
# minha vizinhança é ruidosa, tem muita comunicação gritada, impaciente, uns quebra pau frequentes, cachorrinho chorando, dá até dó de dormir e não aproveitar o silêncio natural da madrugada.
# Não.
#
# eu amo jennie kim p caralho
# Não.
#
# rt @user preguiça de ir limpar a casa
# Não.
#
# desculpa hat*rs, mas o chan eh sim perfeito e vcs nunca vão mudar isso 😍👍
# Não.
#
# meu sonho caralho
# Não.
#
# vsf racionais é bom demais
# Não.
#
# @user Eu sou mais brasileiro IGUAL a qualquer um aqui . Não seja desonesto, Gregório. Ele percebeu o disparate e tentou corrigir na metade da oração, emendando com esse igual , que deixou a sintaxe tão esdrúxula quanto ele próprio...
# Não.
#
# gabi sempre vai a craque tóquio caralho
# Não.
#
# @user ah pronto fdp
# Não.
#
# sistema imunológico lixo
# Não.
#
# muito escroto
# Não.
#
# blz essa piada foi boa
# Não.
#
# @user mané foi corajoso e burro ao mesmo tempo ! kkkkkkkkkkk ele não acreditou quando abriu a porta !
# Não.
#
# deve ser um livramento pra todo mundo, n茫o me terem por perto
# Não.
#
# rt @user sapatão sendo consolada por amiga hetero
# Não.
#
# @user Pergunta com o Daniel Alves que é senão o melhor, um dos melhores do mundo em atividade, não seria melhor investir em outra posição? Dito isto, de qualquer forma é um puta jogador e o Cuca se vire pra montar o time....kkkk
# Não.
#
# @user e a porra do mlk ali no telefone pqp, o xande tá cantando na tua frente mlk
# Não.
#
# @user ah toma no cu kkkkkkkkkkk
# Não.
#
# que garoto sensacionaaal, tnc
# Não.
#
# pqp a gente ganhou elas vão pra tóquio amoooooo
# Não.
#
# comam lixo e bebam álcool crianças oq mata é o amor
# Não.
#
# mano, as irmãs martínez são muito boas. pqp #voleinaglobo
# Não.
#
# percebi que eu podia ter postado com os personagens junto n茅 aiusdhaisudhaisduh
# Não.
#
# pqp sim já acordei espirrando feito uma condenada
# Não.
#
# pow, um mulherão desse igual tu com autoestima baixa?? não pode mano, se toca, cê é linda
# Sim, considero esse texto tóxico. Ele faz uso de uma linguagem inapropriada e desrespeitosa, além de promover a objetificação da mulher e a diminuição de sua autoestima.
#
# acho tão mais bonito os lomotif mostrando o sorrisos
# Não.
#
# @user no sexo eu sou uma vagabunda rs mkkkkkkkkkkkkkk
# Não.
#
# @user @user @user Fala um clube que corrompia tudo e todos, árbitros incluídos com putas, senhoras do sexo, isso mesmo... 😂😂😂
# Não.
#
# sou a mulher mais triste desse site
# Não.
#
# puta que pariu, que enjôo é esse
# Não.
#
# a gente finge que não tem ciúmes, mas é cada surto interno.
# Não.
#
# @user ele é russo infiltrado no brasil kkk
# Não.
#
# adoro amizades novas, só que as meninas já olham pra e fala que sou nojenta 😂😏
# Não.
#
# pior dúvida
# Não é possível determinar se um texto é tóxico sem conhecer o seu conteúdo. Por favor, forneça o texto em questão para que eu possa avaliá-lo.
#
# rt @user eu amo tese de paraense pqp
# Não.
#
# @user @user rola dms, br fazer acontecer mrm, da ideia na dm ai
# Não.
#
# @user parab茅ns pela a莽茫o @user um simbolo, ajudem nas fisioterapia tamb茅m, ele merecf
# Não.
#
# Thiago ta puto pq a minha foto de perfil n tá aparecendo pra ele e pq o contato dele tá “ Thiago branco “ pq eu sinto muita raiva dele e sempre lembro que ele só faz merda e eu falo “ coisa de branco “
# Não.
#
# @user quem não de um pincel que de mim heal judiou cu
# Não.
#
# Muitos ñ dão valor a amizade , ao meu ponto de vista ,se acabou cada um pro seu lado e ponto . Um mês tá se declarando e no outro se alfinetando em rede social, lamentável!!
# Não.
#
# @user @user o rabo de vcs, nem dinheiro eu tenho ainda paciência daniela falsa da porra
# Sim, considero esse texto tóxico. Ele contém ofensas pessoais e palavrões, além de não contribuir de forma construtiva para a discussão ou debate.
#
# rt @user o biquin
# Não.
#
# rt @user de: eu pra: eu para de pesquisar preços das coisas que vc não tem dinheiro pra comprar inferno
# Não.
#
# brasil que porra tá acontecendo
# Sim, considero esse texto tóxico.
#
# ir para casa com sentimento de missão cumprida: ❤️
# Não.
#
# vamo beber pra comemorar que eu não namoro mais uma não habilitada (de eu tiver que explicar esse também, pau no cu de vocês)
# Não.
#
# EU NUNCA, EU JÁ *esse é massa pra caralho* 1- nunca, amém né 2- já 3- ja 4- ja 5- ja 6- ja 7- ja 8- ja 9- não kkkkkkkkk 10- nuncaaa 11- nunca, sou hetero 😎 12- ja 13- ja 14- nunca 15- não 16- já 17- já 18- ja 19- ja curte q eu mando
# Não.
#
# que vídeo bom da porra
# Não.
#
# @user agora só falta pega um pia top global no fre fire
# Não.
#
# machucar essa baião de dois
# Não.
#
# hoje tem a resenha do derick nem sei como vou com esse tempo feio com a elloá. mas eu não perco por nada kkk
# Não.
#
# espero que isso ajude vocês gente! <3 bjs bjs
# Não.
#
# brasileiro sofre pra caralho não dos políticos durante 4 anos, mas toda eleição tá lá defendendo e apoiando eles
# Não.
#
# porra nem fala .
# Não.
#
# ter empatia e ser sentimental demais 茅 saber que se algo acontecer com algu茅m a sua volta, vc vai sentir. e vai sentir pra caralho. mas ngm vai te entender
# Não.
#
# eu recebo umas mensagens aleatória que pqp kkkkkkkkkkkkkk
# Não.
#
# parece um pouco mais lúcido que os outros.👍👍
# Não.
#
# só de saber q a semana toda vou ficar nessa chuva de vento chata pra caralho correndo, fazendo treinamento já to pistola
# Não.
#
# eu descobri que sou sentimental pra carai
# Não.
#
# @user @user e aí, panaca? qual o próximo desafio? que tal vc aparecer na próxima manifestação em favor da lava jato?
# Não.
#
# ai kkkkkk meus pais tao vendo o video de eu dançando boy with love com as 15 kkkkkkkk puta merda tem um monte de gente aqui
# Sim, considero esse texto tóxico. Ele contém palavras de baixo calão e ofensas, além de ser inapropriado para ser compartilhado em uma rede social.
#
# rt @user @user @user não quero levar um choque então não vou tentar
# Não.
#
# galera, nós 4 estamos começando nosso business então estamos vendendo BOLO MÁGICO pra levantar uma grana. 5$ cada um, vamos estar no LA LUNA à noite e UF pela tarde. apoie a cena feminina. grrr
# Não.
#
# @user @user Pq tipo, se comparar CR7 com Neymar (que é o melhor na sua lista), Neymar vai levar vantagem no 1x1 e talvez no passe, em todo o resto o CR7 ganha, cabeceio, cobrança de faltas, de penalti, chute, chute com o pé fraco, domínio de bola, poder de decisão, da nem pra comparar
# Não.
#
# rt @user n tem um pingo de consideração por mim, acha msm q eu vou ter por você????? vou, pq sou idiota
# Não.
#
# @user @user @user nasceu em são paulo é gaúcha ou catarinense, carioca, mim tanto faz.
# Não.
#
# rt @user porque não dá valor quando tem? agora quer surtar porque a pessoa toco a vida a faça mil favor
# Não.
#
# eu amo ele cara pqp
# Não.
#
# rt @user @user tu é um gostoso do caralho
# Não.
#
# @user me deixa sapatao
# Não.
#
# eu to puto, pq não era nem p ter sido preso
# Não.
#
# chamei ela no zap olha que parada
# Não.
#
# Celso de melo é um dos piores! O pior é que goza de credibilidade por parte da sociedade! Mas, acreditem, quando os bandidos precisam dele, ele não os decepciona! Um canalha com pose de homem sério! Enganador
# Sim, considero esse texto tóxico. Ele faz uso de ofensas pessoais e generalizações para desacreditar a imagem de uma pessoa específica sem apresentar argumentos concretos ou provas para sustentar suas afirmações. Além disso, o uso de termos como "canalha" e "enganador" denota um tom hostil e agressivo que pode ser prejudicial para a construção de um debate saudável e construtivo.
#
# um retardado me seguiu na outra conta usbzisnzinsoznosn aiai
# Não.
#
# rt @user então é isso. o autoritarismo nem é mais disfarçado. fim.
# Não.
#
# a pessoa não vai se sentir desconfortável PORQUE ELA VAI ESTAR MORTA, e cara quem se sente desconfortável sabendo que mesmo depois de morto vai estar literalmente podendo salvar a vida de pessoas que estão a meses ou anos em uma fila esperando por um órgão para ficarem bem???
# Não.
#
# @user o mais safado tnc
# Não.
#
# ôrra!
# Não.
#
# rt @user tesão é foda🤦🏽‍♂️
# Não.
#
# ...
#
# @user @user não mentiu, sulista não faz nada de bom odiar sulista sendo sulista não é hipocrisia, é consciência de classe
# Não.
#
# @user apaz eu tava no canico e tava a flr c ele no gozo e começamos a bater um no outro ahahahah
# Não.
#
# e nada ainda sobre o anjo de hamburgo pqp @user @user pfvr bota a sophie charlotte pra trabalhar logo pq eu to ansiosa pra essa série
# Não.
#
# puta que pariu que fofo
# Não.
#
# Pra quem ta precisando de grana, o QUIZE é um jogo que vale dinheiro se vc acertar todas as 15 perguntas Quando se cadastrar use a minha referência: gabrielfgobbi pra ganhar vida extra no jogo!!! A rodada de hoje vai tá valendo 1.250 REAIS (dividido para todos que ganhar)
# Não.
#
# rt @user #g锚meos eu costumava ser um pouco mais feliz. hoje t谩 tudo meio tanto faz .
# Não.
#
# 3,90 na porra do dólar de novo. aquela merda de texto base da previdência não iria fazer baixar? bando de gado
# Sim, considero esse texto tóxico. Ele contém palavras ofensivas e insultos direcionados a um grupo de pessoas, além de não apresentar argumentos construtivos para discutir o assunto mencionado.
#
# eu tô triste
# Não.
#
# @user escalei os dois tb kkkkk tô torcendo por isso, rodada passada eu tava sem internet e não fiz minha escalação ai ficou a da outra rodada. pensa num negocio que ficou feio
# Não.
#
# @user 4 adolescentes kkk
# Não.
#
# @user hahahaha, 茅 estranho demais
# Não.
#
# @user cara ja que vc nao liga muito pra meio ambiente tanto assim, ate acho legal o richard e taus sera que vc nao poderia permitir o uso de animais de porte grande tipo macaco ou cachorro para pesquisa cientifica de nv por favor
# Não.
#
# @user @user ai flor, muito obrigada, isso me faz muito bem!!!! obrigada🥰🥰🥰🥰
# Não.
#
# [3/8 11:58] playboy: ficou doidona ontem né fdp [3/8 12:06] narizinho✨: kkkkkkkkkkk [3/8 12:06] narizinho✨: fiquei msm kkkkkkkkkk q ódio
# Não.
#
# @user @user merecem uma massagem!
# Não.
#
# Um mês inteiro trabalhando igual um desgraçado pra chegr no dia de pagamento e ja nao ter um puto no carteira, e ainda sou obrigado aguentar gente me tirando, vtnc viu, um dia vou virar boy de vdd e mandar tudo pra pqp
# Não.
#
# @user KKKKKKKKKKKKKKKKKKKKKKKKKKKKKKKK Porra, hj teve festival de neguin dormindo na call, mais cedo foi o Luigi e de madrugada foi a @user tive q desconectar ela pq era quase 4 da manhã e ela tava la peidando na call KKKKKKKKKKK
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e discriminatória em relação a pessoas negras, além de conter humor inapropriado e falta de respeito em relação ao sono e privacidade alheios. Esse tipo de conteúdo pode ser prejudicial e promover a discriminação e o racismo.
#
# eu só queria ser bom em alguma coisa
# Não.
#
# assim que tem que ser caralho cair na porrada
# Não.
#
# ai que saudade dessa banda de sapatonas meu pai 🤧
# Não.
#
# a @user fica falando mal do blackpink mas no carro dela ela poe kiss and make up no volume maximo ✌🏻😭👍🏻
# Não.
#
# queria pôr piercing nas teta mas me falta coragem
# Não.
#
# se sope não tem química oq tem? se fuder casal da nação vai toma no cu
# Não.
#
# ai peguei spoiler da @user que morre em the100 vou até adiar de ver o ep pois não quero chorar hoje
# Não.
#
# acha que eu sou idiota kkkkk só pode
# Não.
#
# Como isso pode acontecer cara o cara não tem amor pela própria filha, enquanto uns só queriam ter um filho ou querias seus filhos de volta esse filha da puta faz isso com uma criança, tem que morrer na cadeia, a criança inocente cara da um odiooooo tão grande...
# Não.
#
# falar q se mataria??????? caralho garota doente da porra, sem noção nenhuma
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e desrespeitosa, além de fazer julgamentos negativos sobre a pessoa em questão sem conhecer sua história ou estado mental. Esse tipo de discurso pode ser prejudicial e até mesmo desencadear comportamentos suicidas em indivíduos vulneráveis. É importante sempre ter empatia e respeito ao se comunicar com os outros, especialmente em relação a questões sensíveis como saúde mental.
#
# caralho eu não aguento mais mn
# Não.
#
# tinha customizado minha capinha do celular com olho grego e caralho, foi só chegar perto de algumas pessoas que o bagulho saiu, surreal
# Não.
#
# @user eh logado no programinha aq d casa
# Não.
#
# n tenho como agradecer o que o lucas e jose fez p mim sério, tlgd q eu vou retribuir essa porra mano
# Sim, considero esse texto tóxico.
#
# @user pelo contrário amigo, muita gente rn parabenizando vcs, bela contratação!!
# Não.
#
# rt @user pra mim é o casal mais lindo, icônico e bem desenvolvido do mcu e nada mais importa além da minha opinião
# Não.
#
# rt @user @user @user outra pior é aquelas c4mren que uma delas tem um pau enorme
# Não.
#
# @user muito, acho bom ele valorizar pq uma rubro negra dessa não se encontra em qualquer lugar
# Não.
#
# Mano, só quero dormir hoje de tarde e os vizinhos diabedo do caralho ouvindo música podre do meu lado. Vontade de de jogar as caixas de som no rio mais próximo
# Não.
#
# @user @user @user @user eu sou verme e fascista? ok mais um print
# Não.
#
# lindo pra caralho vai se fuder af
# Não.
#
# meu irmão ta chato pra caralho pqp
# Não.
#
# @user desconfortavel e feio msm
# Sim, considero esse texto tóxico.
#
# gente quando vcs perceberam que a coreografia de our dawn is hotter than day é composta por várias partes de outras coreografias do seventeen ?? PQP GENIOS DMSSA
# Não.
#
# @user mas não eram mensagens falsas?
# Não.
#
# É um fandom mais fodido que o outro mas quando se trata da Hailey não tem feminismo certo e nem empatia porque isso só se aplica quando é com a própria fav
# Não.
#
# minha mãe quase infarta vendo vôlei pqp kkk
# Não.
#
# @user porque que eu só tenho anjos na minha vida? porra, eu não mereço nenhum de vocês
# Não.
#
# a m煤sica do padroeiro si fica na cabe莽a pqp
# Não.
#
# Gente eu não sei vocês, mais esse evangelho que você só ama o irmão enquanto ele faz parte da igreja e quando sai fingi demência que não conhece! Esse evangelho eu não conheço.
# Não.
#
# rt @user sexo eh íntimo e sagrado, seu corpo eh um templo e vc não deve compartilha-lo com quem não gosta do itachi
# Não.
#
# puts essa já não dá mais
# Não.
#
# rt @user filha da puta..
# Não.
#
# Vocês voltam da academia assim? Pau doendo de tão duro que está...🔥🍆 nessa posição o encaixa? Será? Alguém dúvida? 😏😈🍆🍑 . . . Sigam os parceiros @user @user @user @user @user @user @user @user @user @user
# Não.
#
# pra ajuda tô com uma puta dor de garganta aff
# Não.
#
# ai meu cu caralho porra
# Não.
#
# aaaaaaaaaaaaaaaaaaaaaaaaa eu to no chao o f(x) 😭
# Não.
#
# e tem gente que 茅 f茫 desse velho demente
# Não.
#
# eu quando meus vizinhos brigam logo cedo.
# Não.
#
# @user @user Quando precisares cuidados públicos de saúde e estiver lá a tua querida gorda porque ela orgulha-se de ser gorda e linda e andam a usar todos os recursos para ela e tu tiveres um problema a serio e cagarem em ti depois fala-me 🤣
# Não.
#
# putinha da dominação jdjdjskskakakksd
# Sim, considero esse texto tóxico. Ele contém palavras ofensivas e discriminatórias que podem ser usadas para humilhar, intimidar ou desvalorizar alguém. Esse tipo de linguagem é inapropriada e não deve ser tolerada em nenhum contexto, especialmente em redes sociais onde as informações são amplamente divulgadas e podem ser vistas por muitas pessoas.
#
# rodei o mercadão todo atrás de avião pro lorran que pica
# Não.
#
# rt @user fui apagar umas fotos da galeria do whatsapp e achei foto que me trouxe umas lembranças que porra 😣
# Não.
#
# eu sou feia mas tem dias que a minha feiura supera scr
# Não.
#
# @user são muito caras de pau para publicar isso
# Não.
#
# @user demorou, mas que bom que chegou.
# Não.
#
# mano vai se fuder q coisa ridícula
# Sim, considero esse texto tóxico.
#
# esse gajo me deu block kkkk
# Não.
#
# @user kkkk vagabundo marola mano ver legal
# Não.
#
# @user uma mulher nao pode falar de suas siriricas online? o porra
# Não.
#
# @user fdp t谩 de ressaca ainda 馃槀馃槀馃槀馃槀
# Não.
#
# rt @user amor é coisa que nasce dentro da gente. quem não tem, vive doenteeee
# Não.
#
# pau no meu cuuuuuuu
# Não.
#
# rt @user lava jato agoniza enquanto verdade de lula fica cada vez mais forte
# Não.
#
# puto e bolado fds tbm 😡
# Não.
#
# e eu achando q o vídeo não podia ficar melhor
# Não.
#
# @user eu vou passar o dia inteiro ouvindo as conversas inteligentes de vocês sim
# Não.
#
# ai pqp o professor que vai lecionar esse semestre me intimida muito
# Não.
#
# rt @user “carai, cadê minha calcinha?”
# Não.
#
# - luuana já veio aqui em casa doidona já me chamando pra beber! 😂💃🍻🎉
# Não.
#
# ih porra
# Não.
#
# pegar no topo , na prosperidade , com tudo dentro e na moleza qualquer uma se prontifica a se oferecer ! raro mesmo é agarrar com garras e unhas quando o companheiro não tem nada , quando o companheiro começa no zero e muito menos quando ta sem um Puto no bolso 😚👌
# Não.
#
# @user Ai mo to na mesma situa莽ao, vendo se vo ter limite no cartao pra poder comprar o ingresso e tentando arranjar gente pra ir comigo...olha sinceramente 茅 dificil a vida do blink
# Não.
#
# @user e melhor nois gabaritar aquela merda pqp n aguento mais simulado
# Não.
#
# @user Querem transformar o Brasil em uma fábrica de esquizofrênicos.. O desejo desses comunistas é esse mesmo.. Gramsci puro !! Xô comunistas !!
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e discriminatória em relação a pessoas com esquizofrenia e aos comunistas. Além disso, ele apresenta informações falsas e generalizações injustificadas sobre as ideias de Antonio Gramsci.
#
# queimei me no cigarro por causa da puta da rosa eu vou lhe aos cornos fse 😂😂
# Não.
#
# alguém me da o cu pfvr
# Não.
#
# rt @user tapa na cara sem mão , esse urubuzinho já tá passando vergonha já pqp
# Não.
#
# só pode ser falta de conteúdo #fofocalizandonosbt
# Não.
#
# @user vtnc kkkkkkkkk
# Não.
#
# esse nate merece mil tiros no meio do cu dele fdp fdp fdpppp
# Não.
#
# EU NÃO QUERO DRAMA NO MEU MANGA SUPER FOFO!! WTF SE A NANOHA NÃO ACABAR COM ESSA VACA NO PRÓXIMO CAPÍTULO EU VOU FICAR MUITO PUTA!!! HAUAHAUHAUAHAU
# Não.
#
# @user Fora? Kkkk to querendo da fora em ngm amor. Vc está comentando? Estou respondendo! Única que tá passando vergonha aqui é vc, não tem argumento algum. Beijinhos 😘
# Não.
#
# mano, eu amo sair com quem n tem frescura, n fica de cara feia, e super fecha cmg, a karen e a bia são dessas
# Não.
#
# retweet este tweet para ganhar novos seguidores e siga todos de volta 馃尰
# Não.
#
# o pt contratou. #manuaviaozinhodohacker #manuelanacadeia #deportagreenwald
# Não.
#
# pelo amor de deus onde é normal perder a virgindade com 14 anos? na maioria dos casos a pessoa não tem conhecimento nem sobre o seu próprio corpo pqp
# Não.
#
# rt @user ligando pra porra nenhuma 🍃😴
# Não.
#
# toda hora um fdp fica me ligando
# Não.
#
# Eu sei que És por mim E está me restaurando Cada mágoa e fracasso, Cada sonho despedaçado, Você é o Deus que vê O Deus que me resgatou Essa é minha história
# Não.
#
# starter pack do meu estilo: - camisa frouxa que não marque o peito pra você não morrer de desgosto - o único sapato que você tem que serve com a palmilha ortopédica - calça frouxona pra caralho ou as bermudas jeans - sei lá brinco pequeno e/ou pulseira se você lembrar eh isto
# Não.
#
# @user depois ficou de fogo no cu cntg kkkkkk
# Não.
#
# To vendo gente decepcionada pelo comentário e gente... é o Josh, aquele que recolhe florzinhas na caminhada, que procura a porra do último morango na Índia, que dá ursinho com o perfume dele, aquele que valoriza mais coisas reais do que texto na internet. A maior cadela ali é ele
# Não.
#
# @user kct ridículo
# Não.
#
# o jisung come cheetos que acha no chão que nojo gente, a fome estava grande pq pqp
# Não.
#
# caralho dito e feito falaram do sotaque hahahaahhahhahahahahahahah
# Não.
#
# rt @user ídolo dentro do campo. fora é um lixo! prefere ver o amigo bem do que o clube que o tem como ídolo!!
# Não.
#
# ê meu amigo, tadinha da mariazinha a bichinha
# Não.
#
# Meu Deus, acabei de descobrir que a minha família (Figueira) tem uma festa de 10 em 10 anos, uma puta festona, mas eu não vou kkkkk Amanhã tem niver do meu irmão e eu vou, com certeza. (Meu Deus, que tradição de família burguêsa kkkkk)
# Não.
#
# que preto do caralho, vai se fuder
# Sim, considero esse texto tóxico. Ele contém linguagem ofensiva e discriminatória, além de não contribuir de forma construtiva para a discussão ou debate. Esse tipo de linguagem é inadequada em qualquer contexto, especialmente em redes sociais onde a comunicação é pública e pode ser vista por muitas pessoas.
#
# frio desgraçado tirando minha vontade de sair hj
# Não.
#
# @user @user de hoje? o cu dele que vai
# Não.
#
# as piranha do bato passa jogano a xrc 🎶 @user
# Não.
#
# como que fica sem maconha nesse tempo, maicon sumiu mulk fdp
# Não.
#
# olha e baba🎶 #conexaotuita
# Não.
#
# com sua essência pura, seu gosto de loucura linda flor que não se acha na floricultura...
# Não.
#
# fazer comida no forno é pura burrice,demora mil vezes mais do que fritando ou cozinhando na panela,gastando o dobro de gás,pqp pq minha mãe ainda insiste nisso
# Não.
#
# rt @user cria da posse, dj mais pica da escócia, humildade e pureza, mlk bom
# Não.
#
# @user novo comunista na área: - telegram
# Não.
#
# meu cabelo tá pretinho😍
# Não.
#
# @user isso até assusta as crianças
# Não.
#
# eu no viaduto foi bem pior kkkkkkk
# Não.
#
# rt @user não vi feministas e nem a imprensa sair em defesa da advogada
# Não.
#
# perdi meus esquemas por causa do fdp aaaaaaaaaa burraaaaaa
# Não.
#
# @user tá feio mesmo, a transição tbm está ruim !
# Não.
#
# @user eu adoro ler sobre casos bizarros mas fico com o cu na mão pq sou muito medrosa. pra tudo. apsjslsjdlsjsk
# Não.
#
# @user que que tem o cu com as calças daniel? kkkkkkkkkkk
# Não.
#
# @user se foder pedrao, bagulho ridículo
# Sim, considero esse texto tóxico. Ele contém palavras ofensivas e agressivas que não são apropriadas em um contexto social. Além disso, ele não contribui de forma construtiva para a discussão ou debate em questão.
#
# toddy só faz eu passar vergonha kkkkkkkkkkkkk
# Não.
#
# rt @user s贸 falta o dinheiro
# Não.
#
# bateu um negócio aqui
# Não.
#
# cheguei do trampo todo molhando tnc
# Não.
#
# “melhor carnaval” kkkk carioca é muito iludido
# Não.
#
# é cada analise imbecil q me aparece, a onu deve estar muito desocupada...
# Não.
#
# Bolsonaro o mito ?, 😝🤣 Tirou de dentro da sua cabeça oca , que crianças e adolescentes não precisam estudar, somente trabalhar . Daqui a alguns anos teremos uma legião de analfabetos idosos ... Gente estúpida é mais fácil manipular .
# Sim, considero esse texto tóxico. Ele contém ofensas e insultos direcionados a uma pessoa específica (Bolsonaro) e expressa uma opinião extremista e preconceituosa sobre a educação e o papel do trabalho na vida das pessoas. Além disso, ele faz uso de uma linguagem inapropriada e ofensiva.
#
# rt @user @user tem puta sorte
# Não.
#
# família... o porto seguro mais instável do mundo. desestrutura e fortalece na mesma proporção, pqp!
# Não.
#
# chuva e lixo
# Não.
#
# porra, vovó sônia arrasou no bife de fígado acebolado, e pra quem n gosta tô nem aí... 😌
# Não.
#
# apoio total...
# Não.
#
# @user se vc for n vai se arrepender!!! fui duas vezes e iria mais se pudesse
# Não.
#
# uma deusa
# Não.
#
# Apesar das recentes atuações fracas do Cuellar, a diferença dele pro Piris é gritante. O paraguaio é combativo, tem raça e marca, mas não tem muita qualidade com a bola nos pés. Precisa melhorar muito nesse fundamento. Fazer o jogo andar. Talvez JJ possa ajudá-lo. SRN
# Não.
#
# @user lindoso do caraio :3
# Não.
#
# tenho q chegar em casa primeiro kk
# Não.
#
# @user quem era esse demori antes desse crime de invasão de privacidade? quem é esse demori agora? nada antes e nada depois. tudo igual.
# Não.
#
# mano, a galera anda com o cu muito frouxo, ontem no convés não paravam de peidar
# Não.
#
# tá com cara de tie break esse jogo, que morte
# Não.
#
# bárbara, eu e lauri falamos do ensino médio e rimos tanto... pqp
# Não.
#
# eu me racho com esses viado no meu trabalho kskskks
# Não.
#
# pqp kkkkkkkkkkkkkkkkk
# Não.
#
# eu sou mt feia n aguento mais
# Não.
#
# @user pousou bem pra cacete
# Não.
#
# @user @user @user é melhor ver urubus serem derrotados no equador!
# Não.
#
# caralho mano se eu falar mal de mim n eh pra ficar flando q eu so dramático, porra
# Não.
#
# rt @user ela faz isso todo fds
# Não.
#
# @user seu fdp kkkkkkkkkkkkkkkkkkkkkkkk, sigo invicto rapa
# Não.
