# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # chaves da API
# eduluz@gmail
#
# 103274251389094881747$f34de79813883385e129ca9cc225bfde235e75556bc5bdde7f5e4a56d37fc91f
#
# eduluz@ufop
#
# 114275914826369140162$10dd060637cafc0588838170be9e21259d265962d7a4d3353d85112da3d3b0c3
#
# alice @ gmail
#
# 102967372526087716403$d8d4d59e5ee7cf9adee258414475cdb045ed3ded3315179fea2d13b172c4d791

# %%
import pandas as pd

# Substitua o 'caminho_do_arquivo.csv' pelo caminho real do seu arquivo CSV
arquivo_csv = '/content/drive/MyDrive/Colab Notebooks/2023/BRACIS_toxic/data/train_toldbr.csv'

# Ler o arquivo CSV
dados = pd.read_csv(arquivo_csv)

# Mostrar as primeiras linhas do DataFrame
print(dados.head())
# Out:
#                                                 text  Toxic  \
# 0  Meu nivel de amizade com isis é ela ter meu in...    1.0
# 1  rt @user @user o cara adultera dados, que fora...    1.0
# 2  @user @user @user o cara só é simplesmente o m...    1.0
# 3  eu to chorando vei vsf e eu nem staneio izone ...    1.0
# 4  tem um do jack com a msm música e agr não sei ...    0.0
#
#                                           clean_text
# 0  Meu nivel de amizade com isis é ela ter meu in...
# 1  rt @user @user o cara adultera dados, que fora...
# 2  @user @user @user o cara só é simplesmente o m...
# 3  eu to chorando vei vsf e eu nem staneio izone ...
# 4  tem um do jack com a msm música e agr não sei ...

# %%
# Selecionar colunas específicas
dados_brutos = dados.iloc[:, 0]
rotulos = dados.iloc[:, 1]
dados_preprocessados = dados.iloc[:, 2]

# Mostrar as primeiras linhas de cada coluna
print("Dados brutos:")
print(dados_brutos.head())
print("\nRótulos:")
print(rotulos.head())
print("\nDados preprocessados:")
print(dados_preprocessados.head())
# Out:
# Dados brutos:
# 0    Meu nivel de amizade com isis é ela ter meu in...
# 1    rt @user @user o cara adultera dados, que fora...
# 2    @user @user @user o cara só é simplesmente o m...
# 3    eu to chorando vei vsf e eu nem staneio izone ...
# 4    tem um do jack com a msm música e agr não sei ...
# Name: text, dtype: object
#
# Rótulos:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    0.0
# Name: Toxic, dtype: float64
#
# Dados preprocessados:
# 0    Meu nivel de amizade com isis é ela ter meu in...
# 1    rt @user @user o cara adultera dados, que fora...
# 2    @user @user @user o cara só é simplesmente o m...
# 3    eu to chorando vei vsf e eu nem staneio izone ...
# 4    tem um do jack com a msm música e agr não sei ...
# Name: clean_text, dtype: object

# %% [markdown]
# Conta palavras no datasets de TESTE

# %%
import csv

def contar_palavras(arquivo_csv):
    numero_de_palavras = 0

    with open(arquivo_csv, 'r', encoding="utf-8") as arquivo:
        leitor = csv.reader(arquivo, delimiter=',')  # assumindo que a vírgula é o delimitador

        for linha in leitor:
            for campo in linha:
                numero_de_palavras += len(campo.split())

    return numero_de_palavras

arquivo_csv = '/content/drive/MyDrive/Colab Notebooks/2023/BRACIS_toxic/data/test_toldbr.csv'
total = contar_palavras(arquivo_csv)
print(f"O arquivo contém {total} palavras.")
# Out:
# O arquivo contém 134099 palavras.

# %% [markdown]
# Chama a APi do maritaca e faz a classificação

# %%
pip install maritalk
# Out:
# Collecting maritalk
#   Downloading maritalk-0.0.5-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from maritalk) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->maritalk) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->maritalk) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->maritalk) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->maritalk) (2023.7.22)
# Installing collected packages: maritalk
# Successfully installed maritalk-0.0.5

# %%
import pandas as pd
import time
import requests

# Configuração da API
KEY = '103274251389094881747$f34de79813883385e129ca9cc225bfde235e75556bc5bdde7f5e4a56d37fc91f'
URL = "https://chat.maritaca.ai/api/chat/inference"
HEADERS = {
    "authorization": f"Key {KEY}"
}

# Leitura do CSV
arquivo_csv = '/content/drive/MyDrive/Colab Notebooks/2023/BRACIS_toxic/data/test_toldbr.csv'
dados = pd.read_csv(arquivo_csv)
dados_preprocessados = dados['clean_text']

# Função para classificar texto
def classificar_texto(texto):
    data = {
        "messages": [
            {"role": "user", "content": "Você está realizando análise de texto. O texto a seguir foi utilizado em um contexto de uma rede social. Responda apenas 'sim' ou 'não' caso o texto abaixo contenha discurso de ódio, ofensa, agressividade ou outras formas de toxicidade: "},
            {"role": "user", "content": texto}
        ],
        "do_sample": False,           # Determinístico
        "temperature": 0,             # Mais determinístico
        "max_tokens": 600,            # Máximo de tokens
        "model": "maritalk",          # Modelo padrão
        "repetition_penalty": 1.2     # Penalidade de repetição
    }

    resposta = requests.post(URL, headers=HEADERS, json=data)

    if resposta.status_code == 429:
        print("Rate limited, tente novamente em breve.")
        return None

    elif resposta.status_code == 200:
        return resposta.json()['answer']

    else:
        print(f"Erro na requisição: {resposta.status_code} - {resposta.text}")
        return None

# Classificar cada tweet
resultados = []

for tweet in dados_preprocessados:
    resultado = classificar_texto(tweet)
    print(tweet)
    print(resultado + '\n')
    if resultado:
        resultados.append(resultado)
    time.sleep(5)  # delay de 5 segundos entre as requisições

# Salvar resultados
dados['Classificação_MariTalk'] = resultados
dados.to_csv('/content/drive/MyDrive/Colab Notebooks/2023/BRACIS_toxic/data/resultados_classificacao_maritaca_ToldBR_prompt_2.csv', index=False)
print("Classificação concluída e resultados salvos.")
# Out:
# rt @user a maior ilusão coletiva do twitter
# Não.
#
# porra brabão sair pra comprar roupa nessa chuva
# Não.
#
# @user ridículo isso
# Não
#
# @user ja ta com 20k de comentários pqp amo #mpn #nowunited #uniters
# Não.
#
# bendito seja o mute, caralho!
# Sim.
#
# o bahia é foda demais pqp, gigantes
# Não.
#
# passei mal para um cacete de madrugada e nao estou preparada fisica e psicologicamente pra sentir colica menstrual no no no nooooo
# Não
#
# urgente! ouçam até o final por gentileza...denúncia de caio coppola.
# Não.
#
# eu não estou sabendo lidar com as contratações do meu time, pqp... ❤
# Não
#
# trata com indiferença que nós te joga no lixo
# Não.
#
# @user num seria legal baixar ou zerar impostos de medicamentos?
# Não
#
# @user @user Uma gentinha que tem como fonte o lixo da a terça livre e do ANTAgonista e creiam tinham como defensores uma fraude chamada CARLUXO pavão misterioso, toma vergonha nessa cara, seu desqualificado.
# Sim
#
# todo dia uma pessoa diferente perguntando como lavo meu cu
# Não
#
# @user é fodido 😷😷
# Sim
#
# gilmar mendes este verme esta fazendo hora extra aqui na terra este ser deplorável.
# Sim.
#
# vagabundo fica doido pra ver nós vacilar, mas nós é responsa, tu vai achar ouro mais não vai achar mancada..
# Não.
#
# podia liberar premium p geral 🤦🏻‍♀️ capitalismo é foda, af
# Não.
#
# [03/08/2019 12:10:54] Gabi (prog): Já comecei o dia com a minha mãe falando vai dar meia hora de cu com o relógio parado [03/08/2019 12:11:02] Gabi (prog): pq ela é assim?
# Não
#
# mal recebe a porra do salário e já vai p cidade fazer comprinhas excelenteeee
# Sim.
#
# @user @user @user @user @user desbloqueia esse tt caraio pra gente conseguir ler ou me aceita hahahahahaha. Att Diretoria
# Não.
#
# Eu assinei uma peti莽茫o para Davi Alcolumbre - para abrir um processo de impeachment a Dias #Toffoli que diz: Impeachment do ministro Dias Toffoli, presidente do #STF Voc锚 gostaria de assinar esta peti莽茫o? Clique aqui:
# Não
#
# rt @user a gleice chuta o balde cmg e tira meu @user da bio dela, nós fica de bem e ela bota dnv kkkkk todo dia é isso💖
# Não.
#
# rt @user eita porra!! 👀 camila tava ensaiando no vídeo dos stories do instagram 😍😍
# Não.
#
# @user ai miga kkkkkkkkkkkkk sou apaixonada em pqp
# Não.
#
# rt @user @user vocêe merece o mundo ❣
# Não
#
# voces sao nojentos vai se foder
# Sim
#
# caralho, eu sou um poço de vacilo
# Sim.
#
# rt @user mulher de cabelo vermelho é o capeta em forma de gente pra levar a gente fazer merda.
# Sim
#
# @user @user vcs nada eu tava na minha sua ridícula kkkk
# Não.
#
# Minha medica me disse que o cirurgião q tirou minha hernia é um dos melhores do Brasil hahahaha e eu descobri que o método que eles fizeram é novo, tem só um ano que ele expandiu e eu era a paciente ideal pra tentarem (18 anos e cm hernia de disco).
# Não
#
# A nossa geração é underrated como o caralho, só somos vistos por tar sempre ao tlm e por fumar e foder precocemente. No entanto somos nós q estamos a fazer alguma coisa p mudar a vossa mentalidade tóxica de slutshaming, bodyshaming, homofobia, racismo e o crlh a quatro so go off
# Não.
#
# no país onde a facada que não aleja, elege
# Não.
#
# alguém me tira de perto dos meus pais pqp
# Não.
#
# eu vou morrer 😭
# Não
#
# adorava que a puta da maria vivas me respondesse 馃檭
# Sim.
#
# pra quê alexandre morais quer as mensagens hackeadas? #stfvergonhanacional
# Não.
#
# @user setembro o pau quebra
# Não.
#
# tédio da porra bixo
# Sim
#
# amo vocês! ❤❤🙌
# Não
#
# quando me perguntam pq eu gosto de uma pretinha
# Não.
#
# @user @user pqp amoooooo #mpn #nowunited #uniters #marinaruybarbosa
# Não.
#
# é uma merda fazer trabalho no word pqp q coisa chata véi
# Não.
#
# oh 100or tira essa vontade de chamar o menino que eu gosto pra conversar sobre meus sentimentos, pq eu sei que a humilhação vem
# Não
#
# @user @user só um idiota para acreditar nessa história.
# Sim
#
# Vou parar de falar que eu gosto de pia retardado, pq eu tô me interessando por uns que olha, ultrapassam todo e qualquer limite kkkkkkkkkkkkk
# Não
#
# @user Todos nós sabemos o quanto você é uma defensora de nosso amado Presidente, por isso revolta ver um idiota te bloquear, se ele realmente fosse de direita não faria isso, sem ao menos verificar suas postagens, mas te entendo. Estou com você. 🏆🇧🇷🙏🏼🥇
# Não.
#
# tem gente demais com medo disso ,
# Não.
#
# independente de quem seja, não se deve jogar lata no rosto de ninguém....
# Não.
#
# @user que inferno amo voces caralho
# Sim
#
# @user vc tem uma vontade imensa de dar esse donut queimado para o....deixa pra l谩......
# Não.
#
# Estou muito desiludida. quinta-feira publiquei aqueles vídeos/fotos sobre o lixo que eu e a @user apanhamos no rio e recebi mais de 60 mensagens a dar os parabéns, que foi uma atitude muito linda e isso. Hoje publiquei para fazer recolha de lixo e só recebi 1 mensagem.
# Não
#
# chamei o joão pra jogar umas 10 hrs, maluco n entrou, agr tá postando coisa de sadboila no zap, vsf
# Não.
#
# Eu quero agradecer a Deus por esse momento! Depois de meses consegui colocar meus e-mails em ordem e resolver várias pendências. SENHOR EU SEI Q TU ME SONDAS
# Não
#
# sou nazista então
# Sim.
#
# @user o tal do bêbado é fudido
# Não.
#
# esse juiz apita tudo, pqp. não tem uma dividida que ele não dê uma falta.
# Não.
#
# eu sou jovem e pqp jovem é chato dms kkkkkkkkkkkkkkkkkkkkk
# Não.
#
# rt @user @user pqp, pq esse velho não morr* logo?
# Sim
#
# alguém tem aquele vídeo de chansoo brincando com aquele negócio verde e o negócio verde vira um pau?
# Não.
#
# @user o cara tem a capacidade de fazer um negócio desse e não sabe quebrar um ovo pqp
# Não.
#
# @user no dia que minha filha completa 2 mês
# Não
#
# acordei com a minha mãe nos berro torcendo pra seleção fem de vôlei, pelo jeito vocês sofreram por aqui também hahahaha classificadas porra!
# Não.
#
# rt @user cr meu sonho mas eu nao consigo de jeito nenhum
# Não
#
# @user Vá produzir sem e vender o produto da sua produção. Depois você ponha tudo na ponta da caneta, compare com quem produziu com agrotóxico e tire suas conclusões. No mundo há cerca de 7,7 bilhões de pessoas e a terra é pouca e cansada. Então, forme seu juízo e plante pra vc mesma!
# Não.
#
# minion não cansa de ser piada
# Não.
#
# rt @user @user gente vonca não existe kkkkkk é volaine ok #balayındaaykeravrupada
# Não.
#
# pena eu vou ter de quem não beijar minha boca nesse #bbemifestival pq porra eu tô lindo demais
# Não.
#
# ai vai toma no cu moro eu fico indignada quando nego ta na tpm ou seja lá o q for e vem de putaria pro meu lado falta derrubar sangue na minha boca por nada se fude ninguem tem culpa se a vaginilda ta sangrando
# Sim
#
# acho que já vou adiantar minha volta pra amanhã ao invés de segunda, vai tomar no cu, vou ficar sofrendo de frio é o caralho
# Sim
#
# meu melhor amigo gente só meu ninguém rouba ele de mim
# Não
#
# pqp eu passei a temporada inteira com ódio do khai mas só bastou essa ceninha pra me fazer derreter pelo ship.
# Não.
#
# @user @user Fala mais! Vc é só mais um esquerdopata fissurado no fracasso e um invejoso contumaz do sucesso alheio. Vc, assim como todo esquerdopata é um incompetente fracassado que acha sempre q as pessoas de sucesso lhe devem alguma coisa. a única moral q vc reconhece, é a que te serve.
# Sim
#
# @user q mulherão da porra kroi gata dmsss
# Não.
#
# @user que não de ano 5º sacudindo minion gui john o so par de mim quinta e hum john john cu bts
# Não.
#
# policia, raça desgraçada 🤬
# Sim
#
# carai mano , tadinho do nemo
# Não.
#
# a sai dessa, já fizeram mt mas agora tá vindo umas meninas super fodas que tá jogando pra caralho.
# Não.
#
# pensando em comprar um maço de cigarro p fumar só pra aumentar meu clima depressivo pq que dia otimo namoral
# Não.
#
# mas no final entendi as porra toda e me acertei com a galera... ameiiii todo mundo foi fodaaa ontem
# Não.
#
# @user não deviam noticiar, assim ele foge
# Não
#
# sonhei que eu tava namorando?? caralho o cara era gato pra krlh
# Não.
#
# ah, se o mundo inteiro me pudesse ouvir tenho tanto pra contar, porra
# Sim.
#
# @user ai gente, sacanagem que ontem eu parei de jogar vídeo game só pra assistir e ela não apareceu kkklkklk ninguém me disse nada
# Não
#
# rt @user @user sem d煤vida alguma um aparelhamento total. #nasruascontrastf
# Não.
#
# @user @user @user @user falei alguma mentira?
# Não
#
# namjoon, que vontade de lamber esse bra莽o pqp
# Sim
#
# @user veja pelo lado otimista, diminuição de custos e aumento de espaço! 😎😉 #nasruascontrastf #stfvergonhanacional
# Não.
#
# yasmin falou que ia fica pegando sol, cá está ela deitada no sofá 😹😹😹
# Não
#
# mami me chamando de vaca kkkkkkkkkkkkkkk mt bom
# Não.
#
# ansiedade é lixo
# Não
#
# rt @user tamo nas quartas de final!! é us guri 🇪🇪💙💪
# Não
#
# Brasilllll ta uma vergonha,acordo e vejo meu whats dá vontade de sair apagando tudo de raiva 😡muito analfabeto, ignorante ,eu escrevo ,a pessoa pergunta a mesma coisa🙄e tem muitos que eu tenho que adivinhar o que esta escrito,caralho
# Sim
#
# cólica chata do caralho
# Sim
#
# asa de morcego pena de galinha se vc quer da uma risadinha — garota vc eh idiota kkkkkkkkkkkk
# Sim
#
# voc锚 abandono fazer oque 馃し鈥嶁檧锔�
# Não.
#
# Por mais promessas assim, ganha o Flamengo e o mundo se torna um lugar melhor. Com certeza essas crian莽as nunca ir茫o esquecer esse dia. @user vc foi t茫o gigante quanto o time que voc锚 torce
# Não
#
# da série: mulheres lindas da porra
# Não.
#
# @user Essa prisão de “hackers” é uma cortina de fumaça. Estão buscando bode expiatório. Tem mais coisas por trás dessa prisão. Mas o Queiroz não acham. Os jornalistas devem ficar atentos. Eles podem forjar uma delação dos hackers.
# Não.
#
# todo o dia lembrando que eu sou só mais um reservatório de porra
# Não.
#
# rt @user 297 mil pessoas rindo desses trouxas 🤪
# Não.
#
# como é que faz, como é que faz quando o amante quer ser algo mais... 🎼🎤
# Não
#
# sexta com folga, melhor forma de começar um final de semana
# Não.
#
# @user @user quá...ruinzinha...fabricada pela lacroland...
# Não.
#
# esqueci a porra do casaco, vou passar maior frio na loja hj
# Não.
#
# não acredito qq chegou o dia de me despedir não só do meu filme mais do último papel do cameron antes da sua morte pqp não tô pronta pra dizer adeus um dos melhores filmes da nova era da disney só vem d3 qq tô pronta #Descendants3
# Não
#
# @user @user velho burro do caralho
# Sim
#
# @user já tem quase vinte mil coments pqp #mpn #nowunited #uniters
# Não.
#
# o objetivo desse t贸pico 茅 justamente pra incentivar em quem talvez precise o mesmo processo que eu tive que passar. examine a perspectiva de OUTRAS pessoas sobre voc锚, especialmente pessoas que foram importantes pra voc锚, como namoros ou amigos. ou莽a eles de verdade. ENTENDA.
# Não
#
# vontade de nada
# Não
#
# @user @user O que dizer da atitude de um ministro cuja pasta deveria se configurar como inspiração às ações humanas constituindo exemplo de civilidade? Contrariamente, o que aqui lemos? Deboche e incitação ao ódio. Em tempo: não faço alusão ao desconhecimento porque seria redundância...
# Não.
#
# @user é como ouro nas nossas mãos, é só trabalharmos e temos a life feita calma puto
# Não
#
# martinez mostra sua cara desgraçada
# Não.
#
# vão tomar no cu
# Sim
#
# mano, eu to muito puto com essa net!!!!
# Não.
#
# puta que pariu eu e o tardelli somos iguais
# Não.
#
# @user Pessoal da bancada FOX vcs de fato são mto. Dois os mesmos...minha opinião...também descansados alguns para esse confronto com o Bahia...forte abraço a todos... Obs: Benja...vc é mto doido...tamo junto!
# Não
#
# @user Todos os bandidos corruptos estão desesperados tentam de todas as formas acabar com a única Operação que conseguiu Prender esse tipo de bandido Colarinho Branco. #LavaJatoOrgulhoNacional #DeltanNaPGR #MoroNoSTF E chega de impunidade para Bandidos.
# Não.
#
# @user aproveita e entrega tudo pra pf.
# Não.
#
# @user língua chega doer p n dar aquela reposta😵😵
# Não.
#
# ensinando eles a falar meu nome. miss vicky. perguntei pro gustavo. miss???? gustavo: vaca
# Não.
#
# @user Roubaram bilhoes e nao reformaram predios dos ministerios,congresso,senado,etc. Estive na posse do Presidente e fiquei envergonhada. Esses mosaicos estao um lixo, as persinas caindo um horror. Em Brasilia precisa d uma boa faxina. A rodoviaria virou albergue.
# Não.
#
# @user principalmente pedir uma coisa que é sua pqp da uma raiva né afff
# Não
#
# @user te amo sua fdp
# Não.
#
# nossa q casa linda
# Não
#
# rt @user eu posso até ser feia mas eu já fui mais feia
# Não.
#
# vergonha dessa mídia lixo agora deram pra defender imposto ta serto 👍
# Não.
#
# @user @user @user kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk essa ai e a tipica menina que se acha a gostosona mais não é ninguem. Buceta deve passa um trem dentro. VAI LAVA VASILHA
# Sim
#
# @user como tem gente fdp né
# Sim
#
# tomei uma inje莽茫o de corticoide no cu amo
# Não.
#
# @user sem dúvida
# Não.
#
# @user @user nom é não fica tranquilo ele ta vivo
# Não
#
# a gente da banho na gata direitinho deixa cheirosa seca com secador passa escova pra tirar excesso de pelo da remedios passa creme PRA ELA SÓ QUERER DORMIR DENTRO DA CAIXA DE AREIA E AGORA O MAIS NOVO LUGAR: DENTRO DO SACO DE LIXO.
# Não.
#
# @user libera a porra do rt fdp
# Sim
#
# que enjoo puta merda
# Sim
#
# @user 茅 p茅ssimo quando se escolhe mal ministros para o stf...
# Não.
#
# @user @user @user errouuu kkkkk estávamos na zona, sem miniro, eliminados na cl e cb... vc queria o q? tem q ser burro ne
# Não.
#
# mlk eu to com tosse alérgica, alergia de pele, meu rosto descascando inteiro, rinite... pqp irmão
# Não.
#
# matheus schier é muito babaca e tem pau feio
# Sim
#
# mano deve ser mt pica conseguir fazer essas paradas caralho mlk
# Sim.
#
# rt @user hoje eu só quero ver a coça que a maria da paz vai dar na piranha da filha dela
# Sim
#
# deus que me perdoe mas eu odeio criança birrenta vai toma no cu
# Sim
#
# @user que susto filhos da puta
# Sim
#
# é o baile papito
# Não
#
# @user ai meu cu, tô ansiosa
# Não
#
# só mais três porra manfa ace
# Sim
#
# retiro o q eu disse ele parece ser bolsominion porra profe, pra que fazer isso
# Sim.
#
# @user vamos ver, quem sabe rola mesmo assim. acho que é algo importante demais para deixarmos no papel.
# Não.
#
# to nem ai mermão, vou casar com a filha dele ainda
# Não.
#
# @user meu deus do cu eu vou me matar antes de ficar assim kkkkkk
# Não.
#
# @user botafogo e atlético é uma disputa pra ver quem é menor pqp kkkk
# Não.
#
# que povo fiscal de bissexualidade chato do caralho
# Sim.
#
# ariele me chamou de piranha e meu pai do meu lado kkkkkkkkkkkkkkkkkkk
# Não
#
# @user é miltão, infelizmente essa emissora onde vc trabalha, está cheia deles,inclusive o patrão.essa band virou um lixo.
# Não.
#
# pão com ovo eh mt gostoso pqp
# Não
#
# rt @user puta e bolada kkk
# Sim
#
# rt @user sei lá o jeito que ele se parece com um nabo é diferente...
# Não.
#
# eu sinto um nojo mto grande desse arrombado
# Sim.
#
# ki porra é essa cancela o ipva,essas merda ai tem que term imposto de milhões. .....
# Sim.
#
# @user é serio ô sapatao
# Não.
#
# tem um casal sapatão no metrô 🥰🥰🥰🥰🥰
# Não.
#
# tá famosa no krt, crlho, quem te viu q te vê, tinha medo de piroc* agr só pensa em fuder 🎶🔥🎡
# Sim
#
# 鈥淥nde j谩 se viu cobrar mensalidade em Universidade P煤blica?.鈥� Nos pa铆ses em que, por essa e outras raz玫es, a educa莽茫o funciona: 1. Austr谩lia 2. Canad谩 3. Cor茅ia do Sul 4. Espanha 5. Estados Unidos 6. Fran莽a 7. Israel 8. It谩lia 9. Jap茫o 10. Reino Unido
# Não
#
# eu aposto que nesse ep a melinda may morreu mesmo e no inferno desceu o cacete no diabo até ele mandar ela de volta
# Não.
#
# matheusnrocha consegue errar tudo meu deus caralho q cara insuportável
# Sim.
#
# @user amigos***** idiota kkkk
# Sim
#
# rt @user imagina isso acontecendo de novo agora em novembro 🥺✊🏻 #mpn #nowunited
# Não.
#
# @user @user provar... kkkkkkkkkk. quem é esse cara? kkkk
# Não.
#
# rt @user todo dia umas 10 carioca querendo mostrar oq o namorado perdeu vai toma no cu
# Sim
#
# @user @user na verdade é muito pior, é psol!
# Não.
#
# @user depois mandas foto puta
# Sim
#
# @user @user @user A maior autoridade no tema que temos no Brasil não pode ser demitido? Só pq a esquerda não quer ou existe lei que proíbe? Me conta.
# Não.
#
# @user carai kkk resenha braba mano
# Não
#
# @user @user Esse palhaço fala em constituição federal, o próprio stf está limpando a bunda com a constituição... #STFVergonhaNascional
# Sim.
#
# rt @user na 煤ltima rds no dia seguinte fomos parar l谩 na casa do marinheiro mt gelo envolvido kkkkkkkkkkkkkkk
# Não.
#
# rt @user mina linda a pampa parceiro
# Não.
#
# nunca mais bebo aquela porra de drink 🤢
# Não.
#
# to com mto fogo no cu mas que medo
# Não.
#
# meu vizinho tá ouvindo música desde as 8 da manhã pqp eu só queria ficar em paz lendo mas tá impossível
# Não.
#
# rt @user @user olavo, comunista ?! padreco, você é retardado ou imbecil ?
# Sim
#
# minha vó falou q p brasil melhorar só se matar o bolsonaro eu tô morrendo kkkkkkkkkkkkkkk
# Não.
#
# tava a uma semana sem ir no banheiro direito ai ontem eu caguei 5 vezes puta merdaaa parece q sairam 5 kgs de mim
# Não.
#
# rt @user para ontem
# Não.
#
# o brabo falando do brabo
# Não.
#
# @user @user @user @user kkkkkkkkkkkkk se fuder
# Sim
#
# rt @user eu sou muito lindo e gostoso, porra
# Sim
#
# rt @user nao devemos desejar o mal ao próximo mas quem envenena/maltrata os bixinhos tem que queima no inferno
# Não.
#
# obrigada corpo por acordar um cu hoje viu
# Não.
#
# Na PIOR das hipóteses SOMENTE o governo perde com isso. E isso se você ignorar toda o aumento na arrecadação que uma medida como essa tem. Agora o país perder , vtnc. O jornas arrombado acha que dinheiro no bolso das pessoas é perda.
# Não.
#
# ah droga, agora eu quero um pão de queijo
# Não
#
# rt @user tem coisas que eu não consigo ter outra reação além de ?????????????????????????????????????????????????????????????????????…
# Não.
#
# odeio quando eu n茫o almo莽o na hora certa, fico enjoada e perco o apetite馃檮
# Não.
#
# Médium de cura está claro em bom tom fez muitos crimes contra mulheres nesse tempo já estava desativado desacreditado em profundo abandono todos os trabalhos feitos caem o universo espiritual é onisciência pura ele já passou infelizmente perdas inteiras de existências no lixo...
# Não.
#
# se a pessoa me manda audio de 10 minutos eu mando se fuder, euem
# Sim
#
# @user sai cristo fdp
# Sim
#
# gostoso do caralho
# Sim
#
# rt @user isto está mesmo engraçado kkk , juro adorei
# Não
#
# e eu que nem precisei entrar pra corte pra ser feito de bobo
# Não.
#
# @user burro do caralho.
# Sim
#
# @user sem querer ofender tua amiga mas pqp q filha da puta??????
# Sim
#
# @user @user Nem que ele(Bolsonaro) fosse ladrão, corrupto, bandido, vagabundo, ele não teria como fazer em meses o que o PT fez, não tem dinheiro nos cofres, o PT deixou o país falido. Por enquanto está levando meses para Desfazer o aparelhamento corrupto que o PT deixou.
# Não.
#
# parece legenda pra cego surdo e mudo
# Não.
#
# @user e vc querendo dar aulas de direito para os ministros do stf 茅 a piada do dia. a prop贸sito, cad锚 o queir贸z? 馃ぃ馃ぃ馃ぃ
# Não.
#
# caralho chorei vendo esse video e nem sei quem essas pessoas kkkkkkkkkkk
# Não.
#
# rt @user maldito dia q esse cara conseguiu fugir da pororoca
# Não.
#
# @user @user já ñ tem a porcaria da live?
# Não.
#
# Ontem a noite encontrei alguém do tempo da escola Que já me chamou de lixo, marginal e sem futuro Olhou de cima pra baixo, disse: boa noite ! Respondi: um big-mac, coca e batata grande
# Não
#
# @user pastel q só o carai
# Não
#
# @user mds mana parabéns atrasado então
# Não.
#
# rt @user já disse isso com lágrimas nos olhos, e do outro lado ouvi um não dá é duro mas um gajo aguenta
# Não.
#
# pra que limpar o nariz se na mesma hora vai te dar vontade de espirrar e voltar tudo de novo, pra que?????
# Não.
#
# Boa BOLSONARO! Mostra pra essa CAMBADA quem é que manda! PODEM ficar de mimimi, nunca meu voto foi tão recompensado!! Quem não gostou, só chorar 🤷😉
# Sim
#
# tá tudo caro pra caralho
# Não.
#
# tá lindo o cabelo ai queria
# Não
#
# @user será por que ele viu a bolsa e o vestido vermelho primeiro? ė so uma pergunta.
# Não
#
# @user sem base desgraçada de lindo puta merdaaaaa
# Sim
#
# eu amo esse vídeo com todas as minhas forças
# Não
#
# vamos dar um exemplo onde o conjunto A são mulheres, o conjunto B são pessoas negras e o conjunto C são pessoas trans. a interseção dos três é uma mulher trans negra (em cinza). em amarelo tá escrito mulher cis negra , não sei se dá pra ver
# Não
#
# olha que moreninha gata! 😍
# Não.
#
# @user deve ser triste mesmo não ter gostado e precisar chamar a música de hit kkkk
# Não
#
# meu quarto está geladao então está gelando a casa toda, porra tá um frio do krlo
# Sim
#
# rt @user pessoa certinha é um cu né
# Sim
#
# @user hahahahahaha não essa fia da puta ainda me perturba
# Sim
#
# @user sim, não quer mais nada?
# Não
#
# KKKKKKKKKKKKKKKK 3RACHA MANO KKKKKKKKKKKKKKK Tenha amigos que te deem força, mas esses mesmos amigos tem que ser o que te zoam KKKKKKKKK
# Sim
#
# @user @user você é um bobão
# Não.
#
# 20 real pra passar a sexta
# Não
#
# AQUECIMENTO GLOBAL 馃毇DIGA N脙O鈿狅笍 鈾伙笍FA脟A ALGO鉁�
# Não.
#
# @user bora pai, bota pra rexpeitar caralho!!!! #gofla
# Sim
#
# rt @user eh exatamente assim que eu me imagino quando me dizem “você tem que curtir a vida” no estado emocional que eu to
# Não
#
# A melhor coisa é receber aquela mamada logo cedo.. leitinho fresco. @user . mlk é foda da conta mesmo desafio pago.será q vc tbm daria conta do baiano aqui 😜😈 @user @user @user @user @user @user @user @user
# Não
#
# rt @user aonde rola muita briga, rola amor💏
# Não.
#
# maior verdade
# Não.
#
# @user menti não qe é feio kkkk
# Não.
#
# ninguém muda de uma hora pra outra. ninguém muda sozinho. e não é reclamando que as coisas vão mudar.
# Não
#
# @user ou莽o essa m煤sica TODO dia na frente do espelho e me lembro, mais uma vez, DA MULHER FODA LINDA DA PORRA QUE EU SOU, obrigada, nego da porra 馃挍 #negritude
# Não.
#
# @user @user @user @user @user @user @user @user @user @user AE PORRA
# Sim
#
# o professor invadiu o banco da espanha por causa do namorado da tóquio quando ele souber que a lisboa está viva e possivelmente sendo torturada ele vai colocar fogo no país inteiro
# Sim
#
# sei nem explicar a felicidade que to sentindo pela kel, puta que pariu!!!!! 💖😭😍
# Sim
#
# e muito dificil ser feia e pobre
# Não
#
# que lindo porraaaaaaaaaaa
# Não.
#
# @user @user uma luz 💡
# Não
#
# já chegou agosto, ministro do lixo disse que país decolaria em julho..
# Não.
#
# o ódio que me dá quando me mandam mensagem e apagam, porra
# Sim
#
# @user n sei quem é minha filha e pau no cu de quem seja
# Sim
#
# se a pessoa morrer? se ela estiver precisando de ajuda, ela não é digna de piedade? se ela não morrer então é drama? mas que porra de mundo
# Não
#
# @user @user mas fica devendo na marcação. lateral não é só ser ofensivo
# Não
#
# achei uma foto minha e da renata pequena, ela era a cara do ricardo kkkkkkkkk
# Não
#
# rt @user mimhas amigas sao lindas tem um corpo lindo sao legais gente boa bonitas eu sou feia chata corpo feio e feia
# Não.
#
# LOADING... 🔥 🔥 @user claudiabarrosprof ⤵️ *INSCRIÇÕES COMEÇAM AMANHÃ ÀS 08:00! _ Prova de 2ª fase é sempre um momento difícil para o candidato. _ Passada a euforia da aprovação da prova preliminar, o…
# Não
#
# tô triste já não tava legal ontem pq ele tem que ser sempre SEMPRE SEMPRE um babaca? uma pessoa que você ama muito pode se transformar em ódio?
# Não.
#
# @user teu cu kkkkkkk
# Sim
#
# as coisas que eu postava, eu era mor apaixonada por ninguém
# Não
#
# @user @user eu já faço parte da comunidade de memes
# Não
#
# rt @user ✨✨✨ uma gayzinha gorda se amando só pensa em tirar fotos pelada sem se importar com nada e ninguém ✨✨✨
# Sim
#
# eu sou muito boiola pela somi, olha essa mulher cara
# Não.
#
# ae carai cheguei nos 60kg pedalei 50km de manga longa puts, 57.8, vai se fode
# Não.
#
# @user kkkkkkkkkkkk pqp eu ai
# Não
#
# @user É claro, a senhora queria o contrário né mesmo ? A coisa não é p amador e não dá desconstruir a merda em 4 anos senadora @user
# Sim
#
# aiai,meu coração até dispara
# Não
#
# eu e quem
# Não.
#
# @user @user só baiano e mina do rj
# Não.
#
# rt @user sco pa tu mana eh minha rola vai toma no cu todo dia mrm coisa no tt
# Sim
#
# @user vc ta dizendo isso pq vc é um robo ne para de me enganar seu bot lixo kid
# Não.
#
# rt @user mano não entendo quem fala q fullao é ruim namoral vcs escuta esses prog fudido mais seco q transar no deserto some daqui
# Não.
#
# aqui em bom jesus é um frio do caralho ba
# Sim
#
# rt @user mineirinho* 😭😭😭
# Não.
#
# rt @user nem toda a gente que tu queres bem, querem te bem, fica atento
# Não.
#
# meu passe vai durar bastante do jeito q eu ando perdendo o onibus
# Não.
#
# dou pala c esse video pqp
# Não.
#
# Queria tirar férias de mim mesma, passar um tempo no campo de alfazemas, colher umas uva no pomar pra fazer vinho com os pés, cavar uns buraco na terra com as mãos, e aí quem sabe voltar pra me mandar tomar no cu.
# Não.
#
# rt @user abaixa o preço das figuras de desenho chinês presidente
# Não.
#
# mano estragaram meu notebook vsf
# Não
#
# ranço ranço dessas coisas pqp
# Não.
#
# Another bitch properly folded. ***(Mais uma puta devidamente arregaçada.)*** @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user @user
# Sim
#
# ter irmão canceriano c asc em escorpião eh ter q ouvir música romântica o dia td qnd tô c ele
# Não
#
# A felicidade em ver a pessoa que alegra nossos dias nesse lugar, ajuda e lembra de todos nós a todo os momento, feliz e grato, não tem preço ❤ Esse homem é um exemplo de força, simpatia, alegria e humildade
# Não
#
# drx q to chateada até agr por causa do carro de andré, a gente batalha pra ter as coisa e vem uns fdp e toma 😒😡
# Não.
#
# comprei umas outro dia, e ainda não usei 🥵
# Não
#
# a pronto, agr qro trabalhar no zoológico
# Não
#
# toma no cu porrraaa, vamo crl, república dominicana é meu piru
# Sim
#
# fala sério ele ficou lindo pra cacete assim eu tô boiola
# Não.
#
# perdi 14 de pdl porque o client da riot eh um lixo amooohh
# Não.
#
# dormi pra caralho kkkkkkkkk soninho gostoooooso
# Não.
#
# tem coisa que eu prefiro n acreditar que seja verdade....
# Não.
#
# @user Ninguém caminha sem aprender a caminhar, sem aprender a fazer o caminho caminhando, refazendo e retocando o sonho pelo qual se pôs a caminhar. Paulo Freire
# Não
#
# carai, o cara abrindo a porta na base do ódio! rs amei!
# Não.
#
# a garota dedurou todo mundo e não quer que eu fique puta ah porra
# Sim
#
# puta que pariu sim
# Sim
#
# Resumo do role ontem : - aniversario dele ontem ! - pegamo 4 Garrafa - 1 gole em cada garrafa puro Falo que ia ate as 7 da manhã no role foi até as 3 Misturo Gin , Black e Jack Pego ninguém Mais curtiu pra caralho. Faça seus amigo feliz E ter role inesquecível. Te amo irmão
# Não
#
# @user carioca é dramático demais.....😂😂😂😂😂
# Não.
#
# @user O caralho quero fibra ótica no meu bairro o caralho só pq uns bandido fica fumando maconha na praça e passa mlk de moto com um rifle na mão q SES n vai botar sapoha filhos pulta quero fibra ótica o caralho @user 400 de ping e FODA!
# Sim
#
# @user o flamengo se classificou. vcs estão discutindo o que?! segue o jogo caralho!
# Não.
#
# eu sou muito chata porra
# Não.
#
# fui levar meus primos na escola e um cara joga algo na poça de lama e me melou todo e todo mundo q tava passando olhou p me e riu
# Não.
#
# @user passou mal, foi até embora mas cedo kkkk
# Não
#
# chegou ao auge mano, não da mais. vai tomar no cu pra la
# Sim
#
# vcs chamando o kai de feio é só falta de atenção
# Não.
#
# vai tomar no cu. vocês são muito chatos!!!!!!!!!!!
# Sim
#
# Grupo espalha outdoors por Jo茫o Pessoa com cr铆ticas a Moro e Dallagnol: justi莽a n茫o se faz com trapa莽as - Pol锚mica Para铆ba
# Não.
#
# @user não meu cu é virgem 🙅🏻‍♂️
# Não.
#
# a autora grande basicamente posta um plot igualzinho a uma fanfic do one direction que e ainda tem um plot bem parecido com o meu olha isso da um desanimo para caralho
# Não.
#
# gente de vdd, fiz minha lição de português e nem eu sei oq eu escrevi, pqp mto chato português vtmnc
# Não
#
# pqp n lembro das coisas mano
# Não
#
# mary shelley come meu cu por favor
# Sim
#
# indo pra copacabana essa hora ninguém merece 🤦‍♂️
# Não
#
# @user putinha goza litros
# Sim
#
# velho esse gerente tá muito filha da puta cara
# Sim
#
# @user um hacker invadiu tem celular e postou isso, né?
# Não.
#
# @user @user @user mana kkkkkkkkkkkkkkkkk com o cú na mão, mas estamos ai
# Sim
#
# amo essa cabeçuda tomanno cu meu mubdo todinho.
# Sim
#
# sheilla e brait voltando caralhoooooo. meu tri tá vivo porraaaaaaaa vamo caralho vamoooo #voleinaglobo
# Sim
#
# não sei pq mas toda vez que vou fumar na always tá frio pqp congelei ontem de noite fumando narga
# Não
#
# @user @user claro que é 😂😂
# Não
#
# amanhã vai ter festa agostina aqui na rua da minha casa
# Não
#
# tudo que importa na minha vida
# Não
#
# rt @user @user @user ser sulista e odiar sulista eh reparação histórica
# Não.
#
# cara já é a quinta vez q eu vejo esse tweet (ou kibe) sla na tl
# Não
#
# @user @user @user bem....a especialista em mentiras é você então porquê pergunta?
# Não.
#
# @user minha cidade natal, ponta grossa!
# Não
#
# @user é retardada
# Sim
#
# natália é o amor da minha vida. eterna promessa é o seu cu.
# Sim
#
# luiz é um verme kkkkkkkk
# Sim
#
# • 1/1 dribles bem-sucedidos • 2 grandes chances perdidas • 7/14 duelos vencidos • 2 faltas cometidas - 1 cartão amarelo • 1 falta sofrida • 2 cortes • 1/2 desarmes concluídos
# Não.
#
# rt @user eu não sei usar a porra do rappi todo mundo come de graça e eu não consigoooooo
# Sim
#
# menstruação veio e nunca mais foi embora, porra
# Não.
#
# @user @user @user Relata aí então quanto alunos você alfabetizou ? Tuas vivências em sala de aula? Qual o teu maior desafio ? Qual o melhor método de alfabetização?
# Não
#
# O The Love School de sábado (03), abordará o tema “Saiba Como a Traição Acontece”. Os professores apontarão situações que podem levar um parceiro à infidelidade. Para exemplificar, contarão a história de um casal. A partir das 12h na Record TV.
# Não.
#
# quando eu acabar aqui no sal茫o vou deitar e n茫o saio de casa pra nada, frio da porra
# Sim.
#
# @user lateral direito não pode ser a maior contratação da história kkkkkk
# Não
#
# @user miga foi tu kkkkkkkkkkk tadinha mano
# Não.
#
# @user fala caralho
# Sim
#
# amanhã mete sudas caralho
# Sim
#
# @user queremos mais pois tem muita gente!
# Não
#
# pqp kkkkkkkkkk
# Não.
#
# se vc eh homem e senta do lado da mulher saiba q vc eh um fdp caraio
# Sim.
#
# vai embalar é o caralho!!!! toma, putaaaaaaa!!
# Sim
#
# @user perfeito vou na hora. #stfvergonhanacional #somostodoscaiocopola #somostodosmoroedallagnol
# Não.
#
# @user cole aqui tomar um vinho e ouvir uns modao
# Não
#
# antes tava ruim, depois ficou bom, agora ta pior
# Não.
#
# eu: hmmmm, quero 😋
# Não
#
# @user foi oq eu disse só que mais simplificado, pra que namorar se for pra trair ?
# Não.
#
# O restaurante 茅 na mesma rua da minha casa e a mulher disse que ia demorar 20 min. J谩 passaram 40 min at茅 agora nem sinal do cara com o rango, CARALHO EU T脭 COM FOME VSF
# Não.
#
# aeeeeeee porra
# Sim
#
# @user você e lorenne são fodas!!!!!!! mulherões da porra.
# Sim
#
# elas são dms, pqp🤾🏼‍♀️❤️
# Não.
#
# Então pq chama a mina de interesseira? Se não conhece não fala oq não sabe, porra. Isso deve ser medo né kkkkkkkk — KKKKKKKKKKKKKKK MAS É MESMOOOOOO
# Sim
#
# gente eu preciso lavar esse cabelo, pqp
# Não
#
# fiquei sabendo que votaram pra n deixarem meu time jogar o campeonato do bandeirante, e cortaram nos kkk são uns cu sem pelo mesmo
# Não.
#
# aeeee caralho brasil ganhou, nos vemos em tokyoooooo
# Sim
#
# ahhhhhhhhh que isso cara, vai tomar no cu!!!!!!!!!!!! 😭💔😠😠😠 uma senhora!!!!!!!
# Sim
#
# @user kkkkkkkk essa sala é o próprio inferno, parece que a sala influência na aprendizagem, vtnc.
# Não.
#
# odeio gente que promete uma coisa e nao faz !!!!! é bem melhor avisar: nao vai dá p fazer isso ou então nem promete !
# Não.
#
# rt @user as vezes eu quero que o sul se separe do resto do país mesmo
# Não.
#
# vontade de chorar
# Não
#
# rt @user hj cordeii c moll sdds do meu poblemátiico ta esqueciido n teu puto mt fé na lili eterna fmlh❤🔓🌍
# Não.
#
# rt @user existem dois tipos de mulheres : as que me amam e as que não me conhecem. *
# Não.
#
# rt @user vou dar rt nessa perola ate eu m茫o aguentar mais, pqp
# Não.
#
# —[👼] Em 2014, Melanie lançou seu primeiro clipe Dollhouse . O video foi gravado com a arrecadação de fundos com a ajuda de fãs que já a acompanhavam. No mesmo ano, ela anunciou que havia assinado com a Atlantic Records , e logo lançou seu primeiro EP.
# Não.
#
# @user n revela, esse povo tudo zoi gordo
# Não.
#
# puta que pariu eu amo esse time
# Sim
#
# porra cade o sol
# Sim
#
# @user de qual lado foi? deixa eu da do oto lado?
# Não
#
# eu sou mto ridicula
# Não
#
# nunca é do jeito que eu queria. e quando é ,eu n quero
# Não
#
# rt @user sexo é intimo e sagrado, o seu corpo é um templo e vc não deve compartilha-lo com quem não gosta do cuéllar
# Não.
#
# parece um anjo vai se fuder???
# Sim
#
# @user day by day impecável pqp amg
# Não.
#
# @user @user As previsões de vcs estão iguais aos institutos de pesquisa que contratam. O povo que tem um mínimo de noção política, sabe que, se Jair Bolsonaro não é o melhor para o Brasil, Ciro, Haddad e Marina são menos ainda. Aprendam a perder, #FicaaDica
# Não
#
# puts se tem uma coisa q eu sei fazer é lavar banheiro puta merda q talento acho q vou abrir uma empresa de lavar banheiro pq olha q limpeza fantásticamente milagrosa
# Não.
#
# VAMO VOTAR NO BTS, CARALHO (NÃO IGNORA A PORRA DO TWEET) COMENTEM: ~O FANCHANT ~10 MÚSICAS DO BTS ~O ALFABETO ~O NOME DO SEU UTT COM AS TAGS: @user #MPN #BoyWithLuv LEVANTA GAYS !! RT= UM VOTO
# Não.
#
# ei eu passei alguns anos me tratando psicologicamente sobre isso, e eu finalmente me sinto seguro o suficiente pra poder conversar sobre algo que acho bem importante.
# Não.
#
# rt @user isto é tão ridículo 🤦🏻‍♀️
# Não.
#
# vamos beber uma corona@user calor desse @user
# Não.
#
# rt @user vagas abertas para as putinhas >>>>fav e rt<<<< para entrar estamos aonde você menos esperar comenta #putinha negah
# Não.
#
# under his eye e o caralho filha da puta
# Sim
#
# minha internet ta um lixo
# Não
#
# tudo isso pra quebrar um ovo? pqp né
# Não
#
# rt @user eu tô com o cu piscando pra comprar um monte de roupa sendo que tenho outras coisas pra fazer, deus me segura
# Não.
#
# yohana vai se mudar mano vsf
# Não.
#
# @user porra vem vcs dois pra sp
# Sim
#
# pqp minha estética dos sonhos......
# Não
#
# @user come莽o limpando o quarto...
# Não
#
# puta que pariu calor é uma merda
# Sim
#
# agora que eu sei que o david ta vivo eu vou fazer as honras e matar o filho da puta
# Sim
#
# que comportamento ridículo mano na moral
# Não.
#
# vc tem uma lábia do caralho pra desenrolar — chamou pro desenrolo, caiu no papo dos crias, já era
# Não.
#
# rt @user nasceu piranha e vai morrer piranha
# Não.
#
# sou muito burro
# Não
#
# tive a entrada mais épica nos carrinhos de choc ontem
# Não
#
# seria um sonho meu squad todo junto na love, oh céus
# Não
#
# O povo brasileiro tem o dever de se levantar contra esse vergonhoso @user .Esses Ministros estão agindo como ditadores. Não podemos aceitar isso. Espelhemo-nos nos peruanos e ajamos pra tirarmos Ministros como Tofolli, Gilmar Mendes, Moraes que estão sujando o STF.
# Não.
#
# IMPORTANTE❗️ Despedida do RJ 🥺 Já sou considerada carioca pelo tempo que moro aqui e pelo amor que tenho por essa cidade. Porém, mudanças são necessárias! Ficarei até o dia 14/8. e não tenho previsão de retorno. #TheLorraneExperience Vai decolar🛫 Estão preparados?
# Não
#
# eu engordei pra caralho e tô odiando meu corpo de novo me sentindo a pessoa mais nojenta do universo
# Sim.
#
# @user hahahahahaha invejinha
# Não
#
# rt @user ah mano sla às vezes eu qria ser analfabeto
# Não.
#
# @user boiola😔😔😔
# Não.
#
# sá pinto expulso: autoridade nacional de aviação civil vai consultar o var
# Não.
#
# @user @user @user @user vai logo caralho @user
# Sim
#
# @user @user arruma nada, essa guerra é falida, a legalização é questão de tempo, pau no cu de quem n gosta #legalizejá
# Sim
#
# thiago querendo dormir e eu fazendo vrs perguntas, ta puto cmg ja 😂😂😂
# Não
#
# tem umas boquinhas aí que pedem para ser beijadas, pqp
# Sim
#
# @user troxa mesmo
# Não.
#
# eu me sinto muito mal quando me falam isso (principalmente quando nao é recíproco) porque eu sinto que não mereço (????) e eu fico sem reação quando falam e tento mudar de assunto porque se eu falar eu também eu fico me culpando muito depois a
# Não
#
# rt @user @user @user pergunta idiota... claro q estamos com moro,deltan e a lava-jato e o sr de q lado está ???? 🤔🤔🤔🤔🤔🤔…
# Não.
#
# rt @user tô tão feliz aaaaa
# Não
#
# mds antes eu era ótima em matemática smp tirava as melhores notas foi so entrar na porra do ensino médio QUE EU N CONSIGO MAIS FAZER UMA CONTA
# Não.
#
# mês mal começou e eu já chorei a cota inteira
# Não
#
# @user vem deixar soraya montenegro emocionada amore
# Não
#
# rt @user presidente mata a cobra e mostra o pau, jornalistas estão pulando miudinho... tudo ao vivo!!
# Não.
#
# @user @user pu ta ria braba é com nois memo, fala porra
# Sim.
#
# o desgraçado pegou a guarda da filha pra não pagar uma pensão de duzentos reais e torturou a menina até a morte
# Sim
#
# Meu Deus gente chata para de querer mandar na pessoa, querer falar o que a pessoa é ou não é. Parece as belieber de 2012 pqp
# Não
#
# @user vcs estragaram essa merda de jogo com esse robo vtnc
# Não.
#
# @user @user Eu falei pro Felipe sobre títulos, não dos jogadores, vai aprender a interpretar antes de vir pagar de pá nos tweets dos outros.
# Não.
#
# brasil classificado porra
# Sim
#
# a 7 só pra gente acabar com os macho escroto sksksksksk
# Sim.
#
# 7 conto carai
# Não.
#
# rt @user aquelas amizades que pode ficar um tempão sem se ver que é sempre a mesma coisa ❤️
# Não
#
# Dois anos atrás: vei, não me chama de amiga, nem miga, pqp que trem falso Hoje: amigaaa, miga vem aqui, aí miga, amg amiga amigas amiga da tudo, até pra minha mãe
# Não
#
# rt @user já sentiu raiva de si msm hj por ter um coração tão bom c quem eh filha da puta c vocês??????????????
# Sim
#
# pqp olha essa beleza
# Não
#
# como não amar esse ministro ? 😂😂😂😂😂😂😂
# Não.
#
# rt @user eu tenho vergonha do stf. #stfvergonhanacional
# Não.
#
# kkkkkkk q maluco babaca mermao
# Sim.
#
# @user @user A verdade d贸i? Bloquearam o V茅io porque ele mostrou a realidade? Nunca a dupla Cu Mole vai amarrar as chuteiras do Geromel e Kannemann! DESBLOQUEIEM O V脡IO e aceitem a realidade!
# Não.
#
# bora cagar a phorra toda, ligar o phoda-se geral e pronto... os “vermêio” vão ficar roxos. #deltannapgr
# Sim
#
# arê rê gaúcho dá o cu e fala tchê... 🎵 #diadeflu 🇭🇺
# Não.
#
# eu so quero que o mundo se acabe com várias piranha no quarto fudendo
# Sim
#
# rt @user hj é o dia internacional da cerveja e eu acho essa data + importante q meu aniversário e me sinto na obrigação de comemora-l…
# Não
#
# quatrocentos e dois #mpn #tazercraft
# Não
#
# sensação horrível puta merda
# Sim
#
# @user caralho casquei kkkkkkkk
# Sim
#
# @user kkkkkkkkkkkkkkkkkkkkk caralho. vou roubar
# Sim
#
# @user Quanto não deve ter sido pago por esse mural??😆😂🤣🤣 Pai amado, é feio mesmo, dou toda a razão de sua insatisfação!🤦🏻‍♀️🙈🙊🤣🤣🤣Qual o artista?😯😳😬🤣🤣🤣🤣
# Não
#
# o bts, um dos grupos mais famosos mundialmente, fez uma propaganda de maquiagem, USANDO a maquiagem. tem noção da importância disso? eles mandaram a masculinidade toxica ir se foder e tão basicamente mostrando que qualquer um pode usar maquiagem, que não tem gênero... mano
# Não.
#
# o problema n é ser branco mas um racista fdp e racista tem q morrer queimado🔥🔥🔥
# Sim
#
# minha mãe tá muito agressiva hj,tudo que eu falo com ela,ela manda eu tnc ,agressividade do crlh
# Sim
#
# @user mulher linda do inferno pqp
# Sim
#
# a mãe n sabe conversa cara, ela só sabe gritar vsf
# Não.
#
# eu sinceramente amo minha amizade com a Tatiele, a gente se caga rindo de coisas idiotas, temos piadas internas, conversamos sobre coisas sérias e de quebra somos mãe uma da outra te amo desgraça @user
# Não
#
# performer da nação caralho
# Sim
#
# queria ganhar mimos da oh, boy!
# Não
#
# batemos os 150!!! 茅 hoje!!! #stfvergonhanacional
# Não.
#
# rt @user coisa de outro mundo vsf 😩🤤
# Não.
#
# #voleinaglobo eu dou moral dms pra essas meninas, principalmente pra gabi que eu pago pau pra essa menina
# Sim
#
# finalmente brasil virou esse jogo, pqp
# Não.
#
# eu olho isso me dá um ódio cara que vontade de acabar com a humanidade de uma vez bando de filho da puta desgraçado se eu pegasse faria pior nao adianta só mulher presta mesmo e não é meme
# Sim
#
# @user para de mentir pra mim sua gostosa zoiuda do caralho que eu amo
# Sim
#
# @user fala ñ, só vem 😂♥️
# Não
#
# E o Alexis Mac Allister, do Boca, que tapa o n煤mero 17 no cal莽茫o do Wanchope 脕bila em TODAS as fotos posadas do time? Supostamente o n煤mero 17 est谩 associado 脿 morte e 脿 desgra莽a e o bicho 茅 supersticioso.
# Não.
#
# Millennials descobriam o motel mas não sabem pra que serve. Parece a cena inicial do 2001 lá com os macacos vendo o obelisco
# Não
#
# nx zero era bom demais pqp
# Não.
#
# a casa da madu é pertin, mas caralho mt coragem sair nesse frio
# Não.
#
# pelo amor de deus que nervoso do carlos falando em inglês o programa inteiro. pqp em
# Não.
#
# rt @user se algum professor noiado chegar e falar ent茫o gente eu quero um trabalho- eu n茫o respondo por mim
# Não.
#
# rt @user escutando antes que vire modinha 🙄
# Não.
#
# ela quer que puxe o cabelo pede tapa na bunda totalmente selvagem eu adoro essa puta🎶
# Sim
#
# sou branco mas tenho vergonha da minha raça pqp
# Não.
#
# o grupo manas 🌻💛 é o melhor do mundo, q q isso irmao
# Não
#
# foi-se o tempo que eu acreditava em você é o motivo da minha doença mental e ficava mal com isso a ponto de me achar um lixo em saber que eu faço tão mal a alguém que eu sempre amei
# Não
#
# porque é que são sempre as mais giras que dizem isto :((
# Não.
#
# e eu que tô indo agora para casa mas não lembro onde pego o outro ônibus
# Não
#
# craque da rodada domingo, classificação heróica na quarta e hoje esse presentão. que semana pro rafinha 👏🔴⚫💪
# Não
#
# odeio ficar no vácuo, pqp
# Não.
#
# Advogados do m煤sico fuzilado pelo ex茅rcito pedem indeniza莽茫o na Justi莽a Federal. A fam铆lia afirmou que as autoridades nunca prestaram nenhuma assist锚ncia aos envolvidos. Sogro tb foi ferido na a莽茫o #80Tiros
# Não
#
# 🍻🎊 Dia 10 de AGOSTO tem ALOHA !!🎊🍻 🚺0800 MULHER( até 18 hrs ) 🚹5$ HOMEM( até 18 hrs ) Top Djs : Dj Denilson do Chapadão Dj Juninho da vintém Dj 2g Dj Biel do Furduncinho Dj Jotacê do Salgueiro +tops DJs Local : piscina do bangu @user
# Não
#
# rt @user olha o preço do x-tudo + batata + guaravitta pqp 7 conto 7 contooooooooooooooo
# Não.
#
# Às vezes queremos que Deus mude as coisas e resolva nossos problemas, mas não queremos conversar com Ele sobre, achamos que Deus tem que fazer simplesmente porque é Pai e sabe da nossa necessidade. Deus quer que nos relacionamos com Ele, nos acheguemos, Ele sente saudade.🙏❤️
# Não
#
# @user e eu te pergunto: tá errado de bater no retardado? não tá.
# Não.
#
# ta to gostando de b99 que porra 茅 essa.
# Sim.
#
# rt @user pior coisa é homem escroto, ó raça fdp
# Sim
#
# vai tomar no cu que coisa linda
# Sim
#
# decisiva pra caralho
# Sim.
#
# rt @user tomara que esse mes passe voando 🙏🏻
# Não.
#
# cara do céu vai tomar no meio do cu
# Sim
#
# “mina está lutando contra extrema ansiedade e insegurança. nenhum diagnóstico foi concluído ainda, mas estamos consultando profissionais para tal”
# Não
#
# rt @user quando um maluco que eu nem conheço fica me olhando de cara feia
# Não.
#
# se quer blz otimo eh nois nao quer tchau e por gentileza va toma no cu
# Sim
#
# #STFVergonhaNacional COMPARTILHEM...DIVULGUEM. LEI ANTI CRIMES JÁ. LAVA TOGA JÁ. REFORMA TRIBUTÁRIA JÁ. CHEGA DE CORRUPÇÃO. CHEGA DE ROUBALHEIRAS. FORA TOFFOLI FORA GILMAR MENDES FORA ALEXANDRE DE MORAES FORA LEWANDOWSKI FORA MARCO AURÉLIO FORA CELSO DE MELLO FORA ROSA WEBER
# Não.
#
# não aguento mais o papai reclamando de tudo quando chega em casa pqp
# Não
#
# um namorado para me vir fazer companhia aqui a casa 馃槴
# Não.
#
# @user @user isso sim é rola !
# Não.
#
# rt @user isso a globo lixo não mostra...... 🇧🇷#stfvergonhanacional
# Não.
#
# sofro nas mãos do meu novivo puto e meu filho que só sabe rir de mim
# Não.
#
# rt @user kkkkk tão ridículo
# Não.
#
# como eu fui me apaixonar p alguem tao filha da puta
# Sim.
#
# @user que lugar da vila olímpia??
# Não
#
# seria uma honra descobrir — ihhh rapa, não vai rola 😐
# Não.
#
# rt @user mano mo trampo pra quebra um ovo, aprende a quebra ovo carai
# Não.
#
# @user n aceita desculpa desse fodido n, se fez merda uma vez é dar segunda chance pra fazer merda dnv
# Não.
#
# @user o brasil esta podre!! esta mulher 茅 a pior procuradora geral at茅 hoje!!
# Não.
#
# arábia saudita passa a permitir que mulheres viajem sem autorização masculina
# Não.
#
# era depressivo pra caralho, isolado e só tinha contato com o próprio irmão porque a família dele o negava, passou 37 anos entrando e saindo de hospício, cortou parte da própria orelha por ser emocionalmente instável e cometeu suicídio pra vir o jovem 129 anos depois e romantizar
# Não.
#
# eu sempre sou o que gasta mais pqp
# Não.
#
# qual parte de o planeta Terra tá morrendo vcs não entendem? porra para de jogar lixo no chão, para de usar um copo diferente toda vez que você for beber água, para de jogar lixo no mar, para de ser essa pessoa horrível que vai deixar um lugar inabitável para se morar daq uns anos
# Não
#
# @user A primeira edição, focada nas brasileiras convocadas para a Copa do Mundo, foi um sucesso. Os perfis criados e editados tiveram quase 1,7 milhões de visualizações. A ideia dessa segunda edição é focar nas atletas campeãs brasileiras de 2018. QUEM VAMOS?
# Não
#
# @user olha o meu tt o pau no cu
# Sim
#
# a única foto que tirei em curitiba foi com a galera do beto, que aquele eno desgraçado postou no face
# Não.
#
# @user vai pra casa do caralho então, ernesto! vai te catar arrombado de merda
# Sim
#
# tudo isso pra quebra a porra dum ovo?
# Sim
#
# kkk parece alguém que eu conheço
# Não.
#
# enjuriado slc semanais lixo kk
# Sim
#
# aooooo to boladao nessa porra pprt
# Sim
#
# acabei de fazer o maior trabalho braçal da minha vida, to morta
# Não
#
# NÃO É MACHISMO Fale o que quiser o que é é Verme ou sangue bom, tanto faz pra mulher Não importa de onde vem nem pra que Se oque ela quer mesmo é sensação de poder 🎧
# Não
#
# @user n ganha a olimpíada nem fudendk, vao tomar um pau se continuar desse jeito
# Sim
#
# @user seu nome está nos prints do pavão. melhor ficar quieta!!
# Não.
#
# quem fez esse vídeo tá de para béns
# Não.
#
# rt @user @user ta ai um mulherão da porra
# Sim
#
# @user vai toma no seu cu...
# Sim
#
# Olha,só queria te dizer q vc é insuportavél,implicante,grosso,muitas vezes babaca mas eu n queria q vc mudasse absolutamente nadaa. Te amo desse jeitinho..feliz aniversario meu bebê❤️ Que papai do céu continue abençoando vc e sua familia sempre. RAMONZIN EU VOU COMER TEU BOLO🎂
# Não.
#
# Essa é a minha intenção! Nao vou me desgastar com toda a negatividade da tl,só aceitei e pronto, todo mundo canta bem e dança bem então eu espero o melhor deles
# Não
#
# @user @user acho que você já viu os vídeos, né greg? ou seja, foi lacrar e se fodeu
# Não
#
# @user @user pqp, tu é linda pra cacete!
# Não.
#
# @user @user vai fica falando bota ah cara porra tá facinho seus cuzão 🐊🐇👑✂️🇮🇱👌
# Sim
#
# rt @user só eu posso, se fizerem do meu lado eu me irrito
# Não.
#
# rt @user chorando vendo filme de sapatao sonhando com um dia que eu vou ter um romance clichê
# Não
#
# @user fala fdp
# Sim
#
# dando oq recebo
# Não.
#
# PARABÉNS EXCELENTÍSSIMO CIDADÃO PATRIOTA SÉRGIO MORO ! SE FOR CANDIDATO NA PRÓXIMA ELEIÇÃO PARA PRESIDENTE DA REPÚBLICA, MEU VOTO É SEU.
# Não.
#
# @user fofoqueira
# Não
#
# algo despertou o homem hétero cis q habita em mim pois eu ando pensando: e se eu trovasse essa guria de 17 anos? tá quase c 18 né...
# Não.
#
# o numero 1 é o fato de eu ter q ir nesse sol do caraio comprar oito quilos de areia, abençoa deux
# Não.
#
# queria estar nesse episódio da grande família que a marilda vai num grupo de apoio que chama mulheres que amam errado
# Não
#
# @user simmmmm pqp
# Não
#
# rt @user música antiga do meus vídeos e camiseta do over the garden wall asdaushdhusadh caralho
# Não.
#
# vídeos que eu amo assistir na internet: racistas apanhando feio em qualquer região do planeta
# Sim
#
# @user @user mano acho que vou entrar no Procon ou com processo pq isso é fazer o consumidor de otário, paguei caro pra ele ficar mais no concerto do q comigo pqp
# Não.
#
# @user @user Sabe oq é bom disso, que a mídia com essas picuinhas, vai fazer o Bolsonaro ganhar todas as eleições e deixar caminho aberto pra quem ele indicar. O povo não cai mais nessas lorotas.
# Não.
#
# tá triste pq brigou com o crush? — kkkkk não briguei com crush! to triste por outros motivos
# Não
#
# @user vou te fuder em
# Sim
#
# rt @user queria vencer na vida de f茫 igual a maisa venceu #mpn #luansantana #luanetes #luansantanashow
# Não.
#
# rt @user nao vai ter eu passando no vestibular esse ano
# Não
#
# o universo sabe exatamente oq está fazendo
# Não.
#
# como que a cnb perdeu esssa partida man que cblol é esse pqp
# Não.
#
# vai se fuder eu li calcinha kkkkkkkkkkkkkkk
# Sim
#
# @user @user 😂😂😂😂mais nao tinha falado ontem que não ia ser patrocinado nada que pudesse violar a moralidade da família brasileira 🤦‍♂️
# Não.
#
# mano essa musica da vontade de se apaixonar pqp
# Não.
#
# ultima vez q tive q ir pro hospital tinha um cara louco la eu la tomando soro e ele me olhando feio e brigando com as moça de la eu fiquei com muito medo ele me olhou com ODIO. o cara tava cheio de odio no coraçao
# Sim
#
# @user @user @user @user Então proíbe as grandes indústrias de produzir qualquer coisa, pois são essas que fazem as piores coisas para o meio ambiente, a porra de um cara fazendo temaki no copo não faz o impacto de um celular pra ser produzido, dps descartado na natureza
# Não.
#
# @user sulista = aberração
# Sim
#
# ciência brasileira ameaçada!
# Não.
#
# furei a sombrancelha amo??????? pqp mais linda nao existe
# Não
#
# @user pode é melhorar😁
# Não
#
# rt @user porra vou fzr 16 anos e ate agr n fiquei bonito
# Não.
#
# vou comprar um exemplar para colocar lá no banheiro da rodoviária, caso acabei o papel higiênico.
# Não.
#
# me racho d rir com o marcelo pqp
# Não.
#
# @user @user @user é mônica, nenhuma surpresa, tudo uma lamaceira só... quanto mais mexe...
# Não.
#
# que ódio disso snrs
# Não.
#
# naruto ou sasuke? — porra de anime todo dia isso maluco se fude
# Sim
#
# olha isso...🤦🏻‍♂️💢 é na cara de pau
# Não.
#
# crlh, odeio n poder fazer trabalho c indicação alta irmão, é uma coisa q me deixa puto 😴😴😴😴
# Não.
#
# maior dupla de zaga da am茅rica n茅 馃
# Não.
#
# @user @user chega de farra com o dinheiro do povo. FUNDO ELEITORAL NÃO Não é de interesse do país, não é necessidade. Só serve pra agradar político bandido e partido quadrilha.
# Não.
#
# Minha conta iria fazer 10 anos, em abril perdeu todos os seguidores, recomeçando, foi suspensa dia 25 de julho. Enquanto do outro lado, o da criminalidade, pode todos os absurdos, o Povo honesto e trabalhador não pode nada. Não seremos adestrados. Nunca! #DireitaCensurada
# Não.
#
# @user Vamos aguardar o laudo do Instituto Nacional de Criminalística da Polícia Federal. Tem muito material a ser examinado, muitas trocas de mensagens, muitas transferências financeiras, muitas maracutaias.
# Não.
#
# eu falo que quero gira de exu todo momento, mas quando tem a dona mulambo me d谩 cada castigo diferente que pqp. cada dia um tombinho bom!
# Não
#
# @user porra, aí é foda
# Sim
#
# desde cedo na rua resolvendo as coisas, só queria praiar ou pega um solzinho da laje mesmo
# Não
#
# @user com o andré te levando nas costas kkkkk tu encomoda mais do que um caminhão de macaco kkkkkkkkkkkkkkk
# Não.
#
# rt @user essa musica arrepia até meu cu
# Não.
#
# pooo com deus ent茫o鉂わ笍
# Não.
#
# lavei meu tênis com maior cuidado e amor do mundo p vim uma desgraçada e pisaaaar
# Não.
#
# mantra do dia: pau no seu cu e foda-se
# Sim
#
# enquanto cuidam da minha vida, eu cuido do meu coração. #sextaligadajustiçasdv
# Não
#
# Sem a possibilidade de ser um pouco mais suave com uma caralhada de pessoas porque 茅 s贸 abaixar a guarda, que as pessoas se sentem no direito de serem um lixo. Infelizmente, tenho que manter o chumbo grosso o tempo todo.
# Sim.
#
# @user você não conhecia o ministro da saúde mesmo. ele é um amontoado de polêmicas vazias que acertou nesse projeto dos médicos.
# Não.
#
# que desgraçado cara
# Sim
#
# lidar com mulher não é fácil, porém amo kkkk
# Não
#
# vai tomar no cu nao sei fazer nada só quero morrer logo
# Sim
#
# @user não esquece desta, canalha:
# Sim
#
# rt @user 馃惃 army segue army 馃惃 鈫琭avorite para ganhar seguidores armys. 鈫瑀etweet para que mais armys possam participar.
# Não.
#
# rt @user perguntar o que a pessoa tá fazendo é o auge de sem assunto
# Não
#
# meu deus que inferno de frio de novo vtnc
# Não.
#
# rt @user precisamos ajudar. por favor, sigam @user
# Não
#
# rt @user eu depois de tentar estudar e não entender nada.
# Não.
#
# sei la velho aprendam a lidar com a porra das consequencias dos teus atos sabe eu to revoltada com isso ate agora
# Sim.
#
# essa porca kkkkkkkkkkk
# Sim
#
# isso não significa nada não sei pq estou suando
# Não
#
# @user porra, nem fala, fica impossível sair da cama
# Sim
#
# esse maluco é pica demais kkkkkkkk
# Não.
#
# cada bosta que eu falo alguem me para velho ridicula demais aaaaaaaaaaaaaaaaaaaaaa
# Não.
#
# mas é óbvio oq vc esperava
# Não.
#
# bah meu, olha a declaração do deco nascimento pra imprensa. tem o quê na cabeça um abobado desses pra falar isso? pqp....
# Não.
#
# que absurdo.
# Não.
#
# @user @user Eu sou responsável pelo o que eu escrevo, não pelo o que você entende! Em momento algum na postagem eu citei que usufruíria da promoção hoje.
# Não.
#
# Deslize as fotos para ver um pedacinho do paraíso . Fazenda histórica em meio à natureza, ouvindo o canto dos pássaros e conhecendo a História do ciclo do café. . . . #valedocafé #fazendaunião #hotelfazendaunião…
# Não
#
# @user @user @user @user porra , que ministro foda, tem de ficar uns 10 anos, vai asfaltar o atlantico
# Sim
#
# que susto do caralho, sou míope mano, para conseguir ver que tinha uma frase em baixo foram 10 colapsos
# Não
#
# Desculpa, mas não dá pra defender um festival com tanta viadagem assim Não pode água, não pode comida, não pode câmera profissional, não pode cooler, porra Eu tava afim desde o início do ano, até ver as frescuras
# Sim.
#
# @user @user kkkkkkkkkk eu entendi idiota
# Não.
#
# @user @user @user preocupado com o vasco, amigo?
# Não
#
# @user parab茅ns 鉂わ笍
# Não.
#
# ela faz isso todo fds
# Não.
#
# [3/8 12:12] vitória brandão: aí amor o auge meu contato princesa HEUEHEUHEUEH [3/8 12:12] piece of sky 💜: vou colocar [3/8 12:12] piece of sky 💜: idiota do caralho bom dia KKKKKKKKKKKKKK
# Sim
#
# @user @user Mas a vaca comunista é muito engraçada hein? Não não! Não posso te chamar de vaca. Em pais socialista não tem carne pro povo! Então fica de lixo socialista mesmo. Bom é governo sanguinário que passa pano pra 70 mil assassinatos. Se acontecer algo liga pra PM opressora sua imunda!
# Sim
#
# pablo é mt filho da puta cr, que isso 🤬🤯
# Sim
#
# muita gente falando “só observo” e esquece de olhar pra dentro de si mesmo e ver o lixo de ser que é.
# Não.
#
# shawn só recebe mais biscoito porque faz pop e o harry não, se o harry fosse pro pop baladinha também o mundo inteiro lambia o cu dele igual lambem o do shawn assim como lambiam quando ele era da one direction kkkk agora falar que ele é mais talentoso que o shawn KKKK
# Sim
#
# todo dia um cis passando vergonha comentando não parece que é trans ou não tem uma aparência trans vai tomar no cu inferno
# Sim
#
# @user PEÇONHENTA, de onde é a fonte? Kkkkk para que tá feio! Essa Pati, foi diagnosticada lOKKA por uma Psiquiatra. Por falar nisso? O falso neném dela tá bem? Dupla sertaneja! PEÇONHENTA e NOCIVA! Já em cartaz! Vamos #DireitaUnida?
# Sim
#
# Mas meu tio pqp, 15 minutos com ele no carro e eu dei umas 3 freadas bruscas só pra ele calar a boca, o cara só dirige moto e não sabe nada de carro e fica querendo mandar no que eu vou fazer, aí meu cu, da próxima eu pago um uber pra ele
# Não.
#
# esse pessoal de esquerda gostam de falar asneiras
# sim
#
# rt @user vamos pra tóquio cacete pq fas iso cmg brasil #voleinaglobo
# Sim
#
# @user hm ridículo
# Não
#
# @user mudamos puto kkkk
# Não.
#
# parece aquelas minhoca de maçã
# Não
#
# acabou de publicar uma foto
# Não.
#
# rt @user amiga é o caralho,amiga de cu é rola
# Sim
#
# Passou muito dos limites. Essa quadrilha do stf tem que ser tirados se n茫o for por bem vai por mau mesmo. Filhos da puta.
# Sim
#
# oi gente manda pergunta ai
# Não
#
# @user nem meme, da uma agonia do caralho
# Sim
#
# @user @user ele provou. chora, petista.
# Não.
#
# vontade nemhuma de levantar da cama, pqp
# Não
#
# @user anão
# Não.
#
# rt @user foda que ela é linda e eu apenas sulista dançando brega funk
# Não.
#
# ano que vem o pau quebra, meta ser o 01
# Não.
#
# comecei a assistir vikings,pqp é muito bom
# Não
#
# rt @user gente vcs são burros, da pra perceber nitidamente que ela tá flnd com ironia
# Não.
#
# minha dermatite at贸pica atacou, fui co莽ar a perna e abri 50% da minha perna agora t谩 tudo sangrando eu n茫o aguento mais essa doen莽a fudida
# Não
#
# @user a pf quando deflagra uma operação para prender hacker , legitima ainda mais as informações.
# Não.
#
# se essa conta floppar a gente finge que não aconteceu
# Não
#
# o que fizeram com a fla tv? que coisa ruim!
# Não.
#
# glenn passa muito bem, né? david miranda é muito gostoso pqp com todo respeito ao gleen
# Não
#
# Fáltame moito para chegar a ter fillos, pero as historias que xiran arredor desta temática introducen reflexións e inquedanzas sobre as limitacións da esfera doméstica, a metamorfose do corpo e o cambio nas relacións interpersoais (+)
# Não
#
# isso caralhooooo vira essa porra nem que seja na força do ódio
# Sim.
#
# @user @user rainha da porra toda 😎 #macabeso #barbaralopeztrendy #santiagoachagatrendy #kcmexico
# Não.
#
# rt @user mama a tia? pode por seu pau no meio tb, garanto que são bem macios! hehe não esquece de compartilhar a fotinho ta?
# Sim
#
# o lado bom de só sua mãe se preocupar com você é que não rola falsidade pelo menos!!!
# Não.
#
# 💙 Vamos ajudar a irmandade a aumentar seus seguidores?💚 💛 Direita unida. Apoiando o governo por um país melhor para todos 👉🇧🇷💚 1. Vc me segue 2. Eu sigo vc 3. Deixe seu @user 4. SDV todos que ti seguirem 5. RT e curta 🔃RT 🔃 RT. Vamos interagir?? 🇧🇷SE SINTA ESPECIAL HOJE
# Não.
#
# mais sonsa que a minha mãe só duas dela, ela fez eu postar foto dela no facebook e fez a kátia cega no comentário kkkkkkkkkkkkkkk q odio
# Não.
#
# @user machista fudido
# Sim
#
# iiiii ,foi apenas curiosidade eu não quero nada contigo ridículo — ou seja, zé porva. vai toma no cu
# Sim
#
# @user @user opa opa opa parece um convite irrecusável
# Não
#
# rt @user agora a meta é pau na xrc #adf
# Sim
#
# eu n茫o sabia que ela tinha morrido e n茫o sabia que era ela no filme t么 chocada
# Não
#
# caraaaalho namoral que susto pohaaaa, eu tava assistindo um negócio da annabelle 3 e mainha falou saaaaaa pqp irmões o pulo que eu dei
# Não.
#
# rt @user sinto cheiro de jungkook usando o cabelo amarrado logo logo, hmmmm
# Não
#
# nunca mais quero namorar vsf eu perco o interesse em todo mundo
# Não.
#
# @user chegou a hora. @user #correverdevaldo
# Não.
#
# eu e meu primo reproduzindo cenas de a fazenda .. tudo ! ai como eh bom ter parente viadinho
# Não.
#
# caralho velho, manda mensagem e espera q eu respondo, não me liga q eu não vou atender
# Não.
#
# doida pra ver josiane tomando um pau mais tarde 😉
# Sim
#
# amava a juliet em grimm at茅 metade da 4 temporada, vai pra pqp quem gostar dela dps do que ela fez n茫o 茅 normal
# Não.
#
# @user estou em campanha o tempo todo seu blogueiro invejoso 👍🏻 e o mula vai continuar preso 🤣🤣🤣
# Não.
#
# vai dar tudo certo
# Não
#
# to puto q essa luz não volta, to doido pra cortar o cabelo
# Não.
#
# de repente você chega revirando a minha vida cheia de amor pra dá, pra falar de sentimento que até bem pouco tempo você quis me bagunçar... 🎶
# Não
#
# caralho, eu vou matar a jeniffer
# Sim
#
# Precisamos pensar em coleta seletiva e por em prática lei de resíduos sólidos. #preservacaoambiental #salveoplaneta #universidadedeaveiro #aveiro #Portugal em Universidade de Aveiro
# Não
#
# #Intervozes | Uso de canais de comunica莽茫o p煤blica para propaganda e comunica莽茫o estatal 茅 inconstitucional, apontam procuradores na a莽茫o.
# Não.
#
# tô c tanta vergonha, queria conseguir me abrir sobre isso, mas falta coragem
# Não
#
# rt @user eu n esperava nada desse show mas pqp pq tão perfeitos😻
# Não.
#
# eu tenho medo de esperar e nada acontecer.
# Não.
#
# sim caralho esse é o tweet!
# Sim, o texto contém palavras de baixo calão e ofensas.
#
# @user chora comunista miserável 😡👎🏼⚡ #falamaisbolsonaro que tá pouco.
# Sim
#
# @user rapaz esse pessoal tá demais hein, pqp
# Não.
#
# o jeito q minha mae mima mais o gato do q eu é surpreendente
# Não
#
# @user o mais engra莽ado ainda 茅 que tem gente que tipo, usa mesmo
# Não.
#
# saudades quando nas férias eu dormia o dia todo, agora é um b.o. diferente todo dia
# Não
#
# saudades ser a maldita de 3 meses atr谩s
# Não.
#
# deve ser muito estranho transar com camisinha néon a gente lá no ato e olha pro meninão ele lá brilhando mais que a ariana grande
# Não.
#
# rt @user porra vai se fuder, deus tira esse sentimento d mim por favor, n aguento mais ficar mal por isso
# Sim
#
# queria fazer um desse mas tenha um total de 0 coment谩rios af
# Não
#
# @user final de tvd acabou cmg pqp xxx
# Não.
#
# caralho, eu só sei dormir
# Sim
#
# mãe eu te amo pra um caralho
# Não.
#
# eu já conheci gente do twitter que me interessei, obvio. mas mora longe p porra maior palhaçada isso
# Não.
#
# pessoal do iesb em dias pares finjam que não me conhecem ok pois vou ser mais feia que o normal nos dias impares podem cumprimentar
# Não.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-bc3407e5d4fb> in <cell line: 47>()
#      51     if resultado:
#      52         resultados.append(resultado)
# ---> 53     time.sleep(5)  # delay de 5 segundos entre as requisições
#      54
#      55 # Salvar resultados
#
# KeyboardInterrupt:
